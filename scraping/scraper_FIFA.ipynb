# %% [markdown]
# # Scraping web FIFA players
# https://www.fifaindex.com/players/

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import pandas as pd

url = "https://www.fifaindex.com"
proxies = {
  'http': 'http://10.4.22.5:3128',
  'https': 'https://10.4.22.5:3128',
}

page = requests.get(url)
#page = requests.get(url, proxies=proxies)

# %%
html = page.content
soup = BeautifulSoup(html,'lxml')
right_table=soup.find('table', class_='table table-striped players')

A=[]
B=[]

# %%
for row in right_table.findAll("tr"):
    cells = row.find("td")
    if(cells!=None):
        a = cells.find("a")
        if(a!=None):
            A.append(a["title"])
            B.append(a["href"])

temp_df=pd.DataFrame({'Name':A, 'url' : B})
print(temp_df)
# Out:
#                   Name                                        url
# 0        Sunil Chhetri              /player/190939/sunil-chhetri/
# 1    Cristiano Ronaldo           /player/20801/cristiano-ronaldo/
# 2        Kylian Mbappé         /player/231747/kylian-mbapp%C3%A9/
# 3        Mohamed Salah              /player/209331/mohamed-salah/
# 4             Coutinho                   /player/189242/coutinho/
# 5        Gabriel Jesus              /player/230666/gabriel-jesus/
# 6    Antoine Griezmann          /player/194765/antoine-griezmann/
# 7        Samuel Umtiti              /player/205600/samuel-umtiti/
# 8    Christian Pulisic          /player/227796/christian-pulisic/
# 9         Lionel Messi               /player/158023/lionel-messi/
# 10          Paul Pogba                 /player/195864/paul-pogba/
# 11      Edinson Cavani             /player/179813/edinson-cavani/
# 12  Zlatan Ibrahimović     /player/41236/zlatan-ibrahimovi%C4%87/
# 13         David Alaba                /player/197445/david-alaba/
# 14         Nabil Fekir                /player/216594/nabil-fekir/
# 15          Marquinhos                 /player/207865/marquinhos/
# 16            Paulinho                   /player/187961/paulinho/
# 17      Gelson Martins             /player/227055/gelson-martins/
# 18              Neymar                     /player/190871/neymar/
# 19  Robert Lewandowski         /player/188545/robert-lewandowski/
# 20              Thiago                     /player/189509/thiago/
# 21         Gareth Bale                /player/173731/gareth-bale/
# 22     James Rodríguez       /player/198710/james-rodr%C3%ADguez/
# 23            Casemiro                   /player/200145/casemiro/
# 24       Thomas Müller         /player/189596/thomas-m%C3%BCller/
# 25     Roberto Firmino            /player/201942/roberto-firmino/
# 26       Marco Asensio              /player/220834/marco-asensio/
# 27          Sadio Mané            /player/208722/sadio-man%C3%A9/
# 28                Saúl                  /player/208421/sa%C3%BAl/
# 29     Ousmane Dembélé  /player/231443/ousmane-demb%C3%A9l%C3%A9/
# ..                 ...                                        ...
# 70              Taison                     /player/188803/taison/
# 71      Milan Škriniar        /player/232363/milan-%C5%A1kriniar/
# 72       Nélson Semedo         /player/227928/n%C3%A9lson-semedo/
# 73     Antonio Rüdiger       /player/205452/antonio-r%C3%BCdiger/
# 74             Rafinha                    /player/201400/rafinha/
# 75    Jasper Cillessen           /player/199987/jasper-cillessen/
# 76        Simone Verdi               /player/196889/simone-verdi/
# 77     Mário Fernandes       /player/193525/m%C3%A1rio-fernandes/
# 78        Samuel Eto'o                  /player/9676/samuel-etoo/
# 79        Denis Suárez          /player/205192/denis-su%C3%A1rez/
# 80     Héctor Bellerín  /player/203747/h%C3%A9ctor-beller%C3%ADn/
# 81     Alphonse Areola            /player/193105/alphonse-areola/
# 82        Alan Dzagoev               /player/187735/alan-dzagoev/
# 83        Wayne Rooney                /player/54050/wayne-rooney/
# 84    Alexandr Golovin           /player/225663/alexandr-golovin/
# 85       Óliver Torres         /player/208777/%C3%B3liver-torres/
# 86      Djibril Sidibé        /player/201042/djibril-sidib%C3%A9/
# 87            Escudero                   /player/192679/escudero/
# 88   Emmanuel Adebayor           /player/53050/emmanuel-adebayor/
# 89         David Neres                /player/236632/david-neres/
# 90      Lucas Torreira             /player/223959/lucas-torreira/
# 91          Kurt Zouma                 /player/204311/kurt-zouma/
# 92               Reyes                      /player/111093/reyes/
# 93        Alban Lafont               /player/231691/alban-lafont/
# 94    Lautaro Martínez      /player/231478/lautaro-mart%C3%ADnez/
# 95        Breel Embolo               /player/222357/breel-embolo/
# 96                Jesé                  /player/202515/jes%C3%A9/
# 97        Gareth Barry                 /player/6826/gareth-barry/
# 98     Frenkie de Jong            /player/228702/frenkie-de-jong/
# 99         Miha Mevlja                /player/216742/miha-mevlja/
#
# [100 rows x 2 columns]

# %%
max_page = 603
for i in range(1,max_page):
        #print(i)
        if i < 2:
            url_temp = url+'/players/'
        else: url_temp = url+'/players/'+str(i)+'/'

        while(True):
            print("Obteniendo página " + str(i))
            try:
                page = requests.get(url_temp)
                #page = requests.get(url_temp,proxies=proxies)
            except requests.exceptions.RequestException as e:  # This is the correct syntax
                print(e)
                continue
            break

        html = page.content
        soup = BeautifulSoup(html,'lxml')
        right_table=soup.find('table', class_='table table-striped players')

        for row in right_table.findAll("tr"):
            cells = row.find("td")
            if(cells!=None):
                a = cells.find("a")
                if(a!=None):
                    A.append(a["title"])
                    B.append(a["href"])
        df=pd.DataFrame({'Name':A, 'url' : B})
        #print(df)
df.to_csv('jugadores_enlaces.csv', index = False, encoding = 'utf-8')
# Out:
# Obteniendo página 1
# Obteniendo página 2
# Obteniendo página 3
# Obteniendo página 4
# Obteniendo página 5
# Obteniendo página 6
# Obteniendo página 7
# Obteniendo página 8
# Obteniendo página 9
# Obteniendo página 10
# Obteniendo página 11
# Obteniendo página 12
# Obteniendo página 13
# Obteniendo página 14
# Obteniendo página 15
# Obteniendo página 16
# Obteniendo página 17
# Obteniendo página 18
# Obteniendo página 19
# Obteniendo página 20
# Obteniendo página 21
# Obteniendo página 22
# Obteniendo página 23
# Obteniendo página 24
# Obteniendo página 25
# Obteniendo página 26
# Obteniendo página 27
# Obteniendo página 28
# Obteniendo página 29
# Obteniendo página 30
# Obteniendo página 31
# Obteniendo página 32
# Obteniendo página 33
# Obteniendo página 34
# Obteniendo página 35
# Obteniendo página 36
# Obteniendo página 37
# Obteniendo página 38
# Obteniendo página 39
# Obteniendo página 40
# Obteniendo página 41
# Obteniendo página 42
# Obteniendo página 43
# Obteniendo página 44
# Obteniendo página 45
# Obteniendo página 46
# Obteniendo página 47
# Obteniendo página 48
# Obteniendo página 49
# Obteniendo página 50
# Obteniendo página 51
# Obteniendo página 52
# Obteniendo página 53
# Obteniendo página 54
# Obteniendo página 55
# Obteniendo página 56
# Obteniendo página 57
# Obteniendo página 58
# Obteniendo página 59
# Obteniendo página 60
# Obteniendo página 61
# Obteniendo página 62
# Obteniendo página 63
# Obteniendo página 64
# Obteniendo página 65
# Obteniendo página 66
# Obteniendo página 67
# Obteniendo página 68
# Obteniendo página 69
# Obteniendo página 70
# Obteniendo página 71
# Obteniendo página 72
# Obteniendo página 73
# Obteniendo página 74
# Obteniendo página 75
# Obteniendo página 76
# Obteniendo página 77
# Obteniendo página 78
# Obteniendo página 79
# Obteniendo página 80
# Obteniendo página 81
# Obteniendo página 82
# Obteniendo página 83
# Obteniendo página 84
# Obteniendo página 85
# Obteniendo página 86
# Obteniendo página 87
# Obteniendo página 88
# Obteniendo página 89
# Obteniendo página 90
# Obteniendo página 91
# Obteniendo página 92
# Obteniendo página 93
# Obteniendo página 94
# Obteniendo página 95
# Obteniendo página 96
# Obteniendo página 97
# Obteniendo página 98
# Obteniendo página 99
# Obteniendo página 100
# Obteniendo página 101
# Obteniendo página 102
# Obteniendo página 103
# Obteniendo página 104
# Obteniendo página 105
# Obteniendo página 106
# Obteniendo página 107
# Obteniendo página 108
# Obteniendo página 109
# Obteniendo página 110
# Obteniendo página 111
# Obteniendo página 112
# Obteniendo página 113
# Obteniendo página 114
# Obteniendo página 115
# Obteniendo página 116
# Obteniendo página 117
# Obteniendo página 118
# Obteniendo página 119
# Obteniendo página 120
# Obteniendo página 121
# Obteniendo página 122
# Obteniendo página 123
# Obteniendo página 124
# Obteniendo página 125
# Obteniendo página 126
# Obteniendo página 127
# Obteniendo página 128
# Obteniendo página 129
# Obteniendo página 130
# Obteniendo página 131
# Obteniendo página 132
# Obteniendo página 133
# Obteniendo página 134
# Obteniendo página 135
# Obteniendo página 136
# Obteniendo página 137
# Obteniendo página 138
# Obteniendo página 139
# Obteniendo página 140
# Obteniendo página 141
# Obteniendo página 142
# Obteniendo página 143
# Obteniendo página 144
# Obteniendo página 145
# Obteniendo página 146
# Obteniendo página 147
# Obteniendo página 148
# Obteniendo página 149
# Obteniendo página 150
# Obteniendo página 151
# Obteniendo página 152
# Obteniendo página 153
# Obteniendo página 154
# Obteniendo página 155
# Obteniendo página 156
# Obteniendo página 157
# Obteniendo página 158
# Obteniendo página 159
# Obteniendo página 160
# Obteniendo página 161
# Obteniendo página 162
# Obteniendo página 163
# Obteniendo página 164
# Obteniendo página 165
# Obteniendo página 166
# Obteniendo página 167
# Obteniendo página 168
# Obteniendo página 169
# Obteniendo página 170
# Obteniendo página 171
# Obteniendo página 172
# Obteniendo página 173
# Obteniendo página 174
# Obteniendo página 175
# Obteniendo página 176
# Obteniendo página 177
# Obteniendo página 178
# Obteniendo página 179
# Obteniendo página 180
# Obteniendo página 181
# Obteniendo página 182
# Obteniendo página 183
# Obteniendo página 184
# Obteniendo página 185
# Obteniendo página 186
# Obteniendo página 187
# Obteniendo página 188
# Obteniendo página 189
# Obteniendo página 190
# Obteniendo página 191
# Obteniendo página 192
# Obteniendo página 193
# Obteniendo página 194
# Obteniendo página 195
# Obteniendo página 196
# Obteniendo página 197
# Obteniendo página 198
# Obteniendo página 199
# Obteniendo página 200
# Obteniendo página 201
# Obteniendo página 202
# Obteniendo página 203
# Obteniendo página 204
# Obteniendo página 205
# Obteniendo página 206
# Obteniendo página 207
# Obteniendo página 208
# Obteniendo página 209
# Obteniendo página 210
# Obteniendo página 211
# Obteniendo página 212
# Obteniendo página 213
# Obteniendo página 214
# Obteniendo página 215
# Obteniendo página 216
# Obteniendo página 217
# Obteniendo página 218
# Obteniendo página 219
# Obteniendo página 220
# Obteniendo página 221
# Obteniendo página 222
# Obteniendo página 223
# Obteniendo página 224
# Obteniendo página 225
# Obteniendo página 226
# Obteniendo página 227
# Obteniendo página 228
# Obteniendo página 229
# Obteniendo página 230
# Obteniendo página 231
# Obteniendo página 232
# Obteniendo página 233
# Obteniendo página 234
# Obteniendo página 235
# Obteniendo página 236
# Obteniendo página 237
# Obteniendo página 238
# Obteniendo página 239
# Obteniendo página 240
# Obteniendo página 241
# Obteniendo página 242
# Obteniendo página 243
# Obteniendo página 244
# Obteniendo página 245
# Obteniendo página 246
# Obteniendo página 247
# Obteniendo página 248
# Obteniendo página 249
# Obteniendo página 250
# Obteniendo página 251
# Obteniendo página 252
# Obteniendo página 253
# Obteniendo página 254
# Obteniendo página 255
# Obteniendo página 256
# Obteniendo página 257
# Obteniendo página 258
# Obteniendo página 259
# Obteniendo página 260
# Obteniendo página 261
# Obteniendo página 262
# Obteniendo página 263
# Obteniendo página 264
# Obteniendo página 265
# Obteniendo página 266
# Obteniendo página 267
# Obteniendo página 268
# Obteniendo página 269
# Obteniendo página 270
# Obteniendo página 271
# Obteniendo página 272
# Obteniendo página 273
# Obteniendo página 274
# Obteniendo página 275
# Obteniendo página 276
# Obteniendo página 277
# Obteniendo página 278
# Obteniendo página 279
# Obteniendo página 280
# Obteniendo página 281
# Obteniendo página 282
# Obteniendo página 283
# Obteniendo página 284
# Obteniendo página 285
# Obteniendo página 286
# Obteniendo página 287
# Obteniendo página 288
# Obteniendo página 289
# Obteniendo página 290
# Obteniendo página 291
# Obteniendo página 292
# Obteniendo página 293
# Obteniendo página 294
# Obteniendo página 295
# Obteniendo página 296
# Obteniendo página 297
# Obteniendo página 298
# Obteniendo página 299
# Obteniendo página 300
# Obteniendo página 301
# Obteniendo página 302
# Obteniendo página 303
# Obteniendo página 304
# Obteniendo página 305
# Obteniendo página 306
# Obteniendo página 307
# Obteniendo página 308
# Obteniendo página 309
# Obteniendo página 310
# Obteniendo página 311
# Obteniendo página 312
# Obteniendo página 313
# Obteniendo página 314
# Obteniendo página 315
# Obteniendo página 316
# Obteniendo página 317
# Obteniendo página 318
# Obteniendo página 319
# Obteniendo página 320
# Obteniendo página 321
# Obteniendo página 322
# Obteniendo página 323
# Obteniendo página 324
# Obteniendo página 325
# Obteniendo página 326
# Obteniendo página 327
# Obteniendo página 328
# Obteniendo página 329
# Obteniendo página 330
# Obteniendo página 331
# Obteniendo página 332
# Obteniendo página 333
# Obteniendo página 334
# Obteniendo página 335
# Obteniendo página 336
# Obteniendo página 337
# Obteniendo página 338
# Obteniendo página 339
# Obteniendo página 340
# Obteniendo página 341
# Obteniendo página 342
# Obteniendo página 343
# Obteniendo página 344
# Obteniendo página 345
# Obteniendo página 346
# Obteniendo página 347
# Obteniendo página 348
# Obteniendo página 349
# Obteniendo página 350
# Obteniendo página 351
# Obteniendo página 352
# Obteniendo página 353
# Obteniendo página 354
# Obteniendo página 355
# Obteniendo página 356
# Obteniendo página 357
# Obteniendo página 358
# Obteniendo página 359
# Obteniendo página 360
# Obteniendo página 361
# Obteniendo página 362
# Obteniendo página 363
# Obteniendo página 364
# Obteniendo página 365
# Obteniendo página 366
# Obteniendo página 367
# Obteniendo página 368
# Obteniendo página 369
# Obteniendo página 370
# Obteniendo página 371
# Obteniendo página 372
# Obteniendo página 373
# Obteniendo página 374
# Obteniendo página 375
# Obteniendo página 376
# Obteniendo página 377
# Obteniendo página 378
# Obteniendo página 379
# Obteniendo página 380
# Obteniendo página 381
# Obteniendo página 382
# Obteniendo página 383
# Obteniendo página 384
# Obteniendo página 385
# Obteniendo página 386
# Obteniendo página 387
# Obteniendo página 388
# Obteniendo página 389
# Obteniendo página 390
# Obteniendo página 391
# Obteniendo página 392
# Obteniendo página 393
# Obteniendo página 394
# Obteniendo página 395
# Obteniendo página 396
# Obteniendo página 397
# Obteniendo página 398
# Obteniendo página 399
# Obteniendo página 400
# Obteniendo página 401
# Obteniendo página 402
# Obteniendo página 403
# Obteniendo página 404
# Obteniendo página 405
# Obteniendo página 406
# Obteniendo página 407
# Obteniendo página 408
# Obteniendo página 409
# Obteniendo página 410
# Obteniendo página 411
# Obteniendo página 412
# Obteniendo página 413
# Obteniendo página 414
# Obteniendo página 415
# Obteniendo página 416
# Obteniendo página 417
# Obteniendo página 418
# Obteniendo página 419
# Obteniendo página 420
# Obteniendo página 421
# Obteniendo página 422
# Obteniendo página 423
# Obteniendo página 424
# Obteniendo página 425
# Obteniendo página 426
# Obteniendo página 427
# Obteniendo página 428
# Obteniendo página 429
# Obteniendo página 430
# Obteniendo página 431
# Obteniendo página 432
# Obteniendo página 433
# Obteniendo página 434
# Obteniendo página 435
# Obteniendo página 436
# Obteniendo página 437
# Obteniendo página 438
# Obteniendo página 439
# Obteniendo página 440
# Obteniendo página 441
# Obteniendo página 442
# Obteniendo página 443
# Obteniendo página 444
# Obteniendo página 445
# Obteniendo página 446
# Obteniendo página 447
# Obteniendo página 448
# Obteniendo página 449
# Obteniendo página 450
# Obteniendo página 451
# Obteniendo página 452
# Obteniendo página 453
# Obteniendo página 454
# Obteniendo página 455
# Obteniendo página 456
# Obteniendo página 457
# Obteniendo página 458
# Obteniendo página 459
# Obteniendo página 460
# Obteniendo página 461
# Obteniendo página 462
# Obteniendo página 463
# Obteniendo página 464
# Obteniendo página 465
# Obteniendo página 466
# Obteniendo página 467
# Obteniendo página 468
# Obteniendo página 469
# Obteniendo página 470
# Obteniendo página 471
# Obteniendo página 472
# Obteniendo página 473
# Obteniendo página 474
# Obteniendo página 475
# Obteniendo página 476
# Obteniendo página 477
# Obteniendo página 478
# Obteniendo página 479
# Obteniendo página 480
# Obteniendo página 481
# Obteniendo página 482
# Obteniendo página 483
# Obteniendo página 484
# Obteniendo página 485
# Obteniendo página 486
# Obteniendo página 487
# Obteniendo página 488
# Obteniendo página 489
# Obteniendo página 490
# Obteniendo página 491
# Obteniendo página 492
# Obteniendo página 493
# Obteniendo página 494
# Obteniendo página 495
# Obteniendo página 496
# Obteniendo página 497
# Obteniendo página 498
# Obteniendo página 499
# Obteniendo página 500
# Obteniendo página 501
# Obteniendo página 502
# Obteniendo página 503
# Obteniendo página 504
# Obteniendo página 505
# Obteniendo página 506
# Obteniendo página 507
# Obteniendo página 508
# Obteniendo página 509
# Obteniendo página 510
# Obteniendo página 511
# Obteniendo página 512
# Obteniendo página 513
# Obteniendo página 514
# Obteniendo página 515
# Obteniendo página 516
# Obteniendo página 517
# Obteniendo página 518
# Obteniendo página 519
# Obteniendo página 520
# Obteniendo página 521
# Obteniendo página 522
# Obteniendo página 523
# Obteniendo página 524
# Obteniendo página 525
# Obteniendo página 526
# Obteniendo página 527
# Obteniendo página 528
# Obteniendo página 529
# Obteniendo página 530
# Obteniendo página 531
# Obteniendo página 532
# Obteniendo página 533
# Obteniendo página 534
# Obteniendo página 535
# Obteniendo página 536
# Obteniendo página 537
# Obteniendo página 538
# Obteniendo página 539
# Obteniendo página 540
# Obteniendo página 541
# Obteniendo página 542
# Obteniendo página 543
# Obteniendo página 544
# Obteniendo página 545
# Obteniendo página 546
# Obteniendo página 547
# Obteniendo página 548
# Obteniendo página 549
# Obteniendo página 550
# Obteniendo página 551
# Obteniendo página 552
# Obteniendo página 553
# Obteniendo página 554
# Obteniendo página 555
# Obteniendo página 556
# Obteniendo página 557
# Obteniendo página 558
# Obteniendo página 559
# Obteniendo página 560
# Obteniendo página 561
# Obteniendo página 562
# Obteniendo página 563
# Obteniendo página 564
# Obteniendo página 565
# Obteniendo página 566
# Obteniendo página 567
# Obteniendo página 568
# Obteniendo página 569
# Obteniendo página 570
# Obteniendo página 571
# Obteniendo página 572
# Obteniendo página 573
# Obteniendo página 574
# Obteniendo página 575
# Obteniendo página 576
# Obteniendo página 577
# Obteniendo página 578
# Obteniendo página 579
# Obteniendo página 580
# Obteniendo página 581
# Obteniendo página 582
# Obteniendo página 583
# Obteniendo página 584
# Obteniendo página 585
# Obteniendo página 586
# Obteniendo página 587
# Obteniendo página 588
# Obteniendo página 589
# Obteniendo página 590
# Obteniendo página 591
# Obteniendo página 592
# Obteniendo página 593
# Obteniendo página 594
# Obteniendo página 595
# Obteniendo página 596
# Obteniendo página 597
# Obteniendo página 598
# Obteniendo página 599
# Obteniendo página 600
# Obteniendo página 601
# Obteniendo página 602

# %% [markdown]
# # Información detalle
# Se realiza un escraping sobre cada uno de los jugadores. considerando los enlaces obtenidos anteriormente.

# %%
Name = [];
Nationality = [];
Rating = [];
Height = [];
Weight = [];
Preffered_foot = [];
Birth_date = [];
Age = [];
Preffered_position = [];
Work_rate = [];
Weak_foot = [];
Skill_moves = [];
Teams = [];
National_position = [];
National_kit = [];
Position = [];
Kit = [];
Joining = [];
Contract = [];
Ball_Control = [];
Dribbling = [];
Marking = [];
Sliding = [];
Standing = [];
Aggression = [];
Reaction = [];
Attack = [];
Interceptions = [];
Vision = [];
Composure = [];
Crossing = [];
Short_pass = [];
Long_pass = [];
Acceleration = [];
Stamina = [];
Strength = [];
Balance = [];
Sprint = [];
Agility = [];
Jumping = [];
Heading = [];
Shot_power = [];
Finishing = [];
Long_shots = [];
Curve = [];
Freekick = [];
Penalties = [];
Volleys = [];
GK_Posi = [];
GK_Diving = [];
GK_Kick = [];
GK_Handling = [];
GK_Reflexes = [];

df_done = df;

for i in range(len(df_done),len(df['Name'])):
	Name.append(df['Name'][i])
	url_temp = url+df['url'][i]
	while(True):
		print("Getting page for "+df['Name'][i])
		try:
			page = requests.get(url_temp,proxies=proxies)
		except requests.exceptions.RequestException as e:  # This is the correct syntax
			print(e)
			continue
		break
	html = page.content
	soup = BeautifulSoup(html,'lxml')
	
	Nat = soup.find('h2', class_="subtitle")
	Pos = Nat.find('a')
	Nationality.append(Pos.find(text=True))

	Both = soup.findAll('div',class_="col-lg-4 col-md-5 col-sm-6 col-ms-6 col-xs-12 team")
	
	if(len(Both)==2):
		Type = Both[0].find('div',class_="panel-body")
		Pars = Type.findAll('p')
		if(len(Pars)==4):
			Team = soup.findAll('div', class_="panel-heading")
			Club = Team[1].findAll('a')
			Teams.append(Club[1].find(text=True))
		else:
			Team = soup.findAll('div', class_="panel-heading")
			Club = Team[2].findAll('a')
			Teams.append(Club[1].find(text=True))

	elif(len(Both)==1):
		Team = soup.findAll('div', class_="panel-heading")
		Club = Team[1].findAll('a')
		Teams.append(Club[1].find(text=True))

	else:
		Teams.append("Free agent")

	Panels = soup.find('h3', class_="panel-title")
	Rate = Panels.findAll('span')
	Rating.append(Rate[1].find(text=True))


	right_table=soup.findAll('div', class_='panel-body')
	Para = right_table[0].findAll('p')
	
	Attributes = Para[0].findAll('span')
	Height.append(str(Attributes[0].find(text=True)))
	
	Attributes = Para[1].findAll('span')
	Weight.append(str(Attributes[0].find(text=True)))
	
	Attributes = Para[2].findAll('span')
	temp = ''
	for i in range(len(Attributes)-1):
		temp = temp + str(Attributes[i].find(text=True)) + '/'
	temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
	Preffered_foot.append(str(temp))
	
	Attributes = Para[3].findAll('span')
	Birth_date.append(str(Attributes[0].find(text=True)))
	

	Attributes = Para[4].findAll('span')
	Age.append(str(Attributes[0].find(text=True)))
	
	Attributes = Para[5].findAll('span')
	temp = ''
	for i in range(1,len(Attributes)-1,2):
		temp = temp + str(Attributes[i].find(text=True)) + '/'
	temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
	Preffered_position.append(temp)
	
	Attributes = Para[6].findAll('span')
	temp = ''
	for i in range(len(Attributes)-1):
		temp = temp + str(Attributes[i].find(text=True)) + '/'
	temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
	Work_rate.append(temp)

	Attributes = Para[7].findAll('span', class_="star")
	stars = Attributes[0].findAll('i', class_="fa fa-star fa-lg")
	Weak_foot.append(len(stars))

	Attributes = Para[8].findAll('span', class_="star")
	stars = Attributes[0].findAll('i', class_="fa fa-star fa-lg")
	Skill_moves.append(len(stars))

	done = 0
	if(len(Both)==2):
		Type = Both[0].find('div',class_="panel-body")
		Pars = Type.findAll('p')
		if(len(Pars)==4):
			Para = right_table[2].findAll('p')
			Attributes = Para[0].findAll('span')
			National_position.append(str(Attributes[1].find(text=True)))

			Attributes = Para[1].findAll('span')
			National_kit.append(str(Attributes[0].find(text=True)))
		

			Para = right_table[1].findAll('p')
			Attributes = Para[0].findAll('span')
			Position.append(str(Attributes[1].find(text=True)))

			Attributes = Para[1].findAll('span')
			Kit.append(str(Attributes[0].find(text=True)))

			Attributes = Para[2].findAll('span')
			Joining.append(str(Attributes[0].find(text=True)))
		
			Attributes = Para[3].findAll('span')
			Contract.append(str(Attributes[0].find(text=True)))
			done = done + 2
		else:
			Para = right_table[1].findAll('p')
			Attributes = Para[0].findAll('span')
			National_position.append(str(Attributes[1].find(text=True)))

			Attributes = Para[1].findAll('span')
			National_kit.append(str(Attributes[0].find(text=True)))
		

			Para = right_table[2].findAll('p')
			Attributes = Para[0].findAll('span')
			Position.append(str(Attributes[1].find(text=True)))

			Attributes = Para[1].findAll('span')
			Kit.append(str(Attributes[0].find(text=True)))

			Attributes = Para[2].findAll('span')
			Joining.append(str(Attributes[0].find(text=True)))
		
			Attributes = Para[3].findAll('span')
			Contract.append(str(Attributes[0].find(text=True)))
			done = done + 2
	
	elif(len(Both)==1):
		National_position.append("");
		National_kit.append("");
		
		Para = right_table[1].findAll('p')
		Attributes = Para[0].findAll('span')
		Position.append(str(Attributes[1].find(text=True)))

		Attributes = Para[1].findAll('span')
		Kit.append(str(Attributes[0].find(text=True)))

		Attributes = Para[2].findAll('span')
		Joining.append(str(Attributes[0].find(text=True)))
	
		Attributes = Para[3].findAll('span')
		Contract.append(str(Attributes[0].find(text=True)))

		done = done+1
	
	else:
		National_position.append("");
		National_kit.append("");
		Position.append("");
		Kit.append("");
		Joining.append("");
		Contract.append("");

	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Ball_Control.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Dribbling.append(str(Attributes[1].find(text=True)))


	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Marking.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Sliding.append(str(Attributes[1].find(text=True)))


	Attributes = Para[2].findAll('span')
	Standing.append(str(Attributes[1].find(text=True)))


	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Aggression.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Reaction.append(str(Attributes[1].find(text=True)))

	Attributes = Para[2].findAll('span')
	Attack.append(str(Attributes[1].find(text=True)))

	Attributes = Para[3].findAll('span')
	Interceptions.append(str(Attributes[1].find(text=True)))

	Attributes = Para[4].findAll('span')
	Vision.append(str(Attributes[1].find(text=True)))

	Attributes = Para[5].findAll('span')
	Composure.append(str(Attributes[1].find(text=True)))


	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Crossing.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Short_pass.append(str(Attributes[1].find(text=True)))


	Attributes = Para[2].findAll('span')
	Long_pass.append(str(Attributes[1].find(text=True)))



	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Acceleration.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Stamina.append(str(Attributes[1].find(text=True)))

	Attributes = Para[2].findAll('span')
	Strength.append(str(Attributes[1].find(text=True)))

	Attributes = Para[3].findAll('span')
	Balance.append(str(Attributes[1].find(text=True)))

	Attributes = Para[4].findAll('span')
	Sprint.append(str(Attributes[1].find(text=True)))

	Attributes = Para[5].findAll('span')
	Agility.append(str(Attributes[1].find(text=True)))

	Attributes = Para[6].findAll('span')
	Jumping.append(str(Attributes[1].find(text=True)))



	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	Heading.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	Shot_power.append(str(Attributes[1].find(text=True)))

	Attributes = Para[2].findAll('span')
	Finishing.append(str(Attributes[1].find(text=True)))

	Attributes = Para[3].findAll('span')
	Long_shots.append(str(Attributes[1].find(text=True)))

	Attributes = Para[4].findAll('span')
	Curve.append(str(Attributes[1].find(text=True)))

	Attributes = Para[5].findAll('span')
	Freekick.append(str(Attributes[1].find(text=True)))

	Attributes = Para[6].findAll('span')
	Penalties.append(str(Attributes[1].find(text=True)))

	Attributes = Para[7].findAll('span')
	Volleys.append(str(Attributes[1].find(text=True)))



	done = done + 1;
	
	Para = right_table[done].findAll('p')
	Attributes = Para[0].findAll('span')
	GK_Posi.append(str(Attributes[1].find(text=True)))

	Attributes = Para[1].findAll('span')
	GK_Diving.append(str(Attributes[1].find(text=True)))

	Attributes = Para[2].findAll('span')
	GK_Handling.append(str(Attributes[1].find(text=True)))

	Attributes = Para[3].findAll('span')
	GK_Kick.append(str(Attributes[1].find(text=True)))

	Attributes = Para[4].findAll('span')
	GK_Reflexes.append(str(Attributes[1].find(text=True)))


	df1 = pd.DataFrame({'Name' : Name, 'Nationality': Nationality, 'National_Position' : National_position, 
		'National_Kit' : National_kit,'Club' : Teams,'Club_Position' : Position, 'Club_Kit' : Kit,
		'Club_Joining' : Joining, 'Contract_Expiry' : Contract, 'Rating' : Rating, 'Height' : Height,
		'Weight' : Weight, 'Preffered_Foot': Preffered_foot,'Birth_Date': Birth_date, 'Age': Age, 
		'Preffered_Position' : Preffered_position, 'Work_Rate': Work_rate,'Weak_foot' : Weak_foot,
		'Skill_Moves' : Skill_moves, 'Ball_Control': Ball_Control, 'Dribbling': Dribbling, 'Marking': Marking,
		'Sliding_Tackle': Sliding, 'Standing_Tackle':Standing, 'Aggression':Aggression, 'Reactions': Reaction,
		'Attacking_Position':Attack, 'Interceptions': Interceptions, 'Vision':Vision, 'Composure':Composure,
		'Crossing':Crossing, 'Short_Pass':Short_pass, 'Long_Pass': Long_pass, 'Acceleration':Acceleration,
		'Speed':Sprint, 'Stamina': Stamina, 'Strength': Strength, 'Balance':Balance, 'Agility': Agility,
		'Jumping': Jumping, 'Heading':Heading, 'Shot_Power': Shot_power, 'Finishing':Finishing, 
		'Long_Shots': Long_shots,'Curve':Curve,'Freekick_Accuracy':Freekick, 'Penalties': Penalties,
		'Volleys' : Volleys, 'GK_Positioning': GK_Posi, 'GK_Diving': GK_Diving, 'GK_Kicking':GK_Kick,'GK_Handling':GK_Handling, 'GK_Reflexes': GK_Reflexes})


	cols = ['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club', 'Club_Position', 'Club_Kit',
			'Club_Joining', 'Contract_Expiry', 'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date',
			'Age', 'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves', 'Ball_Control', 'Dribbling',
			'Marking','Sliding_Tackle','Standing_Tackle','Aggression','Reactions','Attacking_Position',
			'Interceptions','Vision','Composure','Crossing', 'Short_Pass','Long_Pass','Acceleration',
			'Speed','Stamina','Strength','Balance','Agility','Jumping','Heading','Shot_Power','Finishing',
			'Long_Shots','Curve','Freekick_Accuracy','Penalties','Volleys','GK_Positioning','GK_Diving',
			'GK_Kicking','GK_Handling','GK_Reflexes']

	df1 = df1[cols]
	print(df1[['Name','Nationality','Rating']])
	df1.to_csv('FullData(Edit2).csv', index = False, encoding = 'utf-8')
