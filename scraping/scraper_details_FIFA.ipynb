# %% [markdown]
# # Información detalle
# Se realiza un escraping sobre cada uno de los jugadores. considerando los enlaces obtenidos anteriormente.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import pandas as pd

url = "https://www.fifaindex.com"
proxies = {
  'http': 'http://10.4.22.5:3128',
  'https': 'https://10.4.22.5:3128',
}

page = requests.get(url)

# %%
countries = ["Argentina", "Australia", "Belgium", "Brazil", "Colombia", "Costa Rica", "Croatia", "Denmark", "Egypt", 
             "England", "France", "Germany", "Iceland", "Iran", "Japan", "Korea Republic", "Mexico", "Morocco", "Nigeria", 
             "Panama", "Peru", "Poland", "Portugal", "Russia", "Saudi Arabia", "Senegal", "Serbia", "Spain", "Sweden", 
             "Switzerland", "Tunisia", "Uruguay"]

df = pd.read_csv("jugadores_enlaces.csv")
df.head()
# Out:
#      Country               Name                                 url
# 0      India      Sunil Chhetri       /player/190939/sunil-chhetri/
# 1   Portugal  Cristiano Ronaldo    /player/20801/cristiano-ronaldo/
# 2     France      Kylian Mbappé  /player/231747/kylian-mbapp%C3%A9/
# 3  Argentina       Lionel Messi        /player/158023/lionel-messi/
# 4      Egypt      Mohamed Salah       /player/209331/mohamed-salah/

# %%
# filtro de jugadores de países mundialistas
booleans = []
for i in df.Country:
    if i in countries:
        booleans.append(True)
    else:
        booleans.append(False)

filtro = pd.Series(booleans)

df = df[filtro]
df = df.reset_index()
df = df.drop(columns=['Country', 'index'])
df.head(10)
# Out:
#                 Name                                 url
# 0  Cristiano Ronaldo    /player/20801/cristiano-ronaldo/
# 1      Kylian Mbappé  /player/231747/kylian-mbapp%C3%A9/
# 2       Lionel Messi        /player/158023/lionel-messi/
# 3      Mohamed Salah       /player/209331/mohamed-salah/
# 4             Neymar              /player/190871/neymar/
# 5  Antoine Griezmann   /player/194765/antoine-griezmann/
# 6      Gabriel Jesus       /player/230666/gabriel-jesus/
# 7     Lucas Torreira      /player/223959/lucas-torreira/
# 8       Thomas Lemar        /player/213565/thomas-lemar/
# 9     Gelson Martins      /player/227055/gelson-martins/

# %%
# Total de jugadores con país en mundial
df.shape
# Out:
# (12190, 2)

# %%
Name = [] 
Nationality = [] 
Rating = [] 
Height = [] 
Weight = [] 
Preffered_foot = [] 
Birth_date = [] 
Age = [] 
Preffered_position = [] 
Work_rate = [] 
Weak_foot = [] 
Skill_moves = [] 
Teams = [] 
National_position = [] 
National_kit = [] 
Position = [] 
Kit = [] 
Joining = [] 
Contract = [] 
Ball_Control = [] 
Dribbling = [] 
Marking = [] 
Sliding = [] 
Standing = [] 
Aggression = [] 
Reaction = [] 
Attack = [] 
Interceptions = [] 
Vision = [] 
Composure = [] 
Crossing = [] 
Short_pass = [] 
Long_pass = [] 
Acceleration = [] 
Stamina = [] 
Strength = [] 
Balance = [] 
Sprint = [] 
Agility = [] 
Jumping = [] 
Heading = [] 
Shot_power = [] 
Finishing = [] 
Long_shots = [] 
Curve = [] 
Freekick = [] 
Penalties = [] 
Volleys = [] 
GK_Posi = [] 
GK_Diving = [] 
GK_Kick = [] 
GK_Handling = [] 
GK_Reflexes = []

# %%
df['Name'][5]
# Out:
# 'Antoine Griezmann'

# %%
min = 0
max = len(df['Name'])
for i in range(min, max):
    #print(i)
    Name.append(df['Name'][i])
    url_temp = url+df['url'][i]
    #print("url: " + url_temp)
    while(True):
        #if(i%100 == 0):
        print("Obteniendo datos para " + df['Name'][i])
        try:
            #page = requests.get(url_temp,proxies=proxies)
            page = requests.get(url_temp)
        except requests.exceptions.RequestException as e:  # This is the correct syntax
            print(e)
            continue
        break
    html = page.content
    soup = BeautifulSoup(html,'lxml')
    
    Nat = soup.find('h2', class_="subtitle")
    Pos = Nat.find('a')
    Nationality.append(Pos.find(text=True))
    
    Both = soup.findAll('div',class_="col-lg-4 col-md-5 col-sm-6 col-ms-6 col-xs-12 team")
    
    if(len(Both)==2):
        Type = Both[0].find('div',class_="panel-body")
        Pars = Type.findAll('p')
        if(len(Pars)==4):
            Team = soup.findAll('div', class_="panel-heading")
            Club = Team[1].findAll('a')
            Teams.append(Club[1].find(text=True))
        else:
            Team = soup.findAll('div', class_="panel-heading")
            Club = Team[2].findAll('a')
            Teams.append(Club[1].find(text=True))
    elif(len(Both)==1):
        Team = soup.findAll('div', class_="panel-heading")
        Club = Team[1].findAll('a')
        Teams.append(Club[1].find(text=True))
    
    else:
        Teams.append("Free agent")
        
    Panels = soup.find('h3', class_="panel-title")
    Rate = Panels.findAll('span')
    Rating.append(Rate[1].find(text=True))
    
    right_table=soup.findAll('div', class_='panel-body')
    Para = right_table[0].findAll('p')
    
    Attributes = Para[0].findAll('span')
    Height.append(str(Attributes[0].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Weight.append(str(Attributes[0].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    temp = ''
    
    for k in range(len(Attributes)-1):
        temp = temp + str(Attributes[k].find(text=True)) + '/'
    temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
    Preffered_foot.append(str(temp))
    
    Attributes = Para[3].findAll('span')
    Birth_date.append(str(Attributes[0].find(text=True)))
    
    Attributes = Para[4].findAll('span')
    Age.append(str(Attributes[0].find(text=True)))
    
    Attributes = Para[5].findAll('span')
    temp = ''
    
    for k in range(1,len(Attributes)-1,2):
        temp = temp + str(Attributes[k].find(text=True)) + '/'
    temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
    Preffered_position.append(temp)
    
    Attributes = Para[6].findAll('span')
    temp = ''
    
    for k in range(len(Attributes)-1):
        temp = temp + str(Attributes[k].find(text=True)) + '/'
    temp = temp + str(Attributes[len(Attributes)-1].find(text=True))
    Work_rate.append(temp)
    
    Attributes = Para[7].findAll('span', class_="star")
    stars = Attributes[0].findAll('i', class_="fa fa-star fa-lg")
    Weak_foot.append(len(stars))
    
    Attributes = Para[8].findAll('span', class_="star")
    stars = Attributes[0].findAll('i', class_="fa fa-star fa-lg")
    Skill_moves.append(len(stars))
    
    done = 0
    if(len(Both)==2):
        Type = Both[0].find('div',class_="panel-body")
        Pars = Type.findAll('p')
        if(len(Pars)==4):
            Para = right_table[2].findAll('p')
            Attributes = Para[0].findAll('span')
            National_position.append(str(Attributes[1].find(text=True)))
            
            Attributes = Para[1].findAll('span')
            National_kit.append(str(Attributes[0].find(text=True)))
            
            Para = right_table[1].findAll('p')
            Attributes = Para[0].findAll('span')
            Position.append(str(Attributes[1].find(text=True)))
            
            Attributes = Para[1].findAll('span')
            Kit.append(str(Attributes[0].find(text=True)))
            
            Attributes = Para[2].findAll('span')
            Joining.append(str(Attributes[0].find(text=True)))
            
            Attributes = Para[3].findAll('span')
            Contract.append(str(Attributes[0].find(text=True)))
            done = done + 2
        else:
            Para = right_table[1].findAll('p')
            Attributes = Para[0].findAll('span')
            National_position.append(str(Attributes[1].find(text=True)))
            
            Attributes = Para[1].findAll('span')
            National_kit.append(str(Attributes[0].find(text=True)))
            
            Para = right_table[2].findAll('p')
            Attributes = Para[0].findAll('span')
            Position.append(str(Attributes[1].find(text=True)))
            
            Attributes = Para[1].findAll('span')
            Kit.append(str(Attributes[0].find(text=True)))
            
            Attributes = Para[2].findAll('span')
            Joining.append(str(Attributes[0].find(text=True)))
            
            Attributes = Para[3].findAll('span')
            Contract.append(str(Attributes[0].find(text=True)))
            done = done + 2
            
    elif(len(Both)==1):
        National_position.append("");
        National_kit.append("");
        
        Para = right_table[1].findAll('p')
        Attributes = Para[0].findAll('span')
        Position.append(str(Attributes[1].find(text=True)))
        
        Attributes = Para[1].findAll('span')
        Kit.append(str(Attributes[0].find(text=True)))
        
        Attributes = Para[2].findAll('span')
        Joining.append(str(Attributes[0].find(text=True)))
        
        Attributes = Para[3].findAll('span')
        Contract.append(str(Attributes[0].find(text=True)))
        
        done = done+1
        
    else:
        National_position.append("");
        National_kit.append("");
        Position.append("");
        Kit.append("");
        Joining.append("");
        Contract.append("");
        
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Ball_Control.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Dribbling.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Marking.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Sliding.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    Standing.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Aggression.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Reaction.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    Attack.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[3].findAll('span')
    Interceptions.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[4].findAll('span')
    Vision.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[5].findAll('span')
    Composure.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Crossing.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Short_pass.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    Long_pass.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Acceleration.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Stamina.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    Strength.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[3].findAll('span')
    Balance.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[4].findAll('span')
    Sprint.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[5].findAll('span')
    Agility.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[6].findAll('span')
    Jumping.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    Heading.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    Shot_power.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    Finishing.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[3].findAll('span')
    Long_shots.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[4].findAll('span')
    Curve.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[5].findAll('span')
    Freekick.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[6].findAll('span')
    Penalties.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[7].findAll('span')
    Volleys.append(str(Attributes[1].find(text=True)))
    
    done = done + 1;
    
    Para = right_table[done].findAll('p')
    Attributes = Para[0].findAll('span')
    GK_Posi.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[1].findAll('span')
    GK_Diving.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[2].findAll('span')
    GK_Handling.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[3].findAll('span')
    GK_Kick.append(str(Attributes[1].find(text=True)))
    
    Attributes = Para[4].findAll('span')
    GK_Reflexes.append(str(Attributes[1].find(text=True)))
    
    df1 = pd.DataFrame({'Name' : Name, 'Nationality': Nationality, 'National_Position' : National_position, 
            'National_Kit' : National_kit,'Club' : Teams,'Club_Position' : Position, 'Club_Kit' : Kit,
            'Club_Joining' : Joining, 'Contract_Expiry' : Contract, 'Rating' : Rating, 'Height' : Height,
            'Weight' : Weight, 'Preffered_Foot': Preffered_foot,'Birth_Date': Birth_date, 'Age': Age, 
            'Preffered_Position' : Preffered_position, 'Work_Rate': Work_rate,'Weak_foot' : Weak_foot,
            'Skill_Moves' : Skill_moves, 'Ball_Control': Ball_Control, 'Dribbling': Dribbling, 'Marking': Marking,
            'Sliding_Tackle': Sliding, 'Standing_Tackle':Standing, 'Aggression':Aggression, 'Reactions': Reaction,
            'Attacking_Position':Attack, 'Interceptions': Interceptions, 'Vision':Vision, 'Composure':Composure,
            'Crossing':Crossing, 'Short_Pass':Short_pass, 'Long_Pass': Long_pass, 'Acceleration':Acceleration,
            'Speed':Sprint, 'Stamina': Stamina, 'Strength': Strength, 'Balance':Balance, 'Agility': Agility,
            'Jumping': Jumping, 'Heading':Heading, 'Shot_Power': Shot_power, 'Finishing':Finishing, 
            'Long_Shots': Long_shots,'Curve':Curve,'Freekick_Accuracy':Freekick, 'Penalties': Penalties,
            'Volleys' : Volleys, 'GK_Positioning': GK_Posi, 'GK_Diving': GK_Diving, 'GK_Kicking':GK_Kick,'GK_Handling':GK_Handling, 'GK_Reflexes': GK_Reflexes})
    
    cols = ['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club', 'Club_Position', 'Club_Kit',
            'Club_Joining', 'Contract_Expiry', 'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date',
            'Age', 'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves', 'Ball_Control', 'Dribbling',
            'Marking','Sliding_Tackle','Standing_Tackle','Aggression','Reactions','Attacking_Position',
            'Interceptions','Vision','Composure','Crossing', 'Short_Pass','Long_Pass','Acceleration',
            'Speed','Stamina','Strength','Balance','Agility','Jumping','Heading','Shot_Power','Finishing',
            'Long_Shots','Curve','Freekick_Accuracy','Penalties','Volleys','GK_Positioning','GK_Diving',
            'GK_Kicking','GK_Handling','GK_Reflexes']
    
    df1 = df1[cols]

print(df1[['Name','Nationality','Rating']])
# Out:
# Obteniendo datos para Cristiano Ronaldo
# Obteniendo datos para Kylian Mbappé
# Obteniendo datos para Lionel Messi
# Obteniendo datos para Mohamed Salah
# Obteniendo datos para Neymar
# Obteniendo datos para Antoine Griezmann
# Obteniendo datos para Gabriel Jesus
# Obteniendo datos para Lucas Torreira
# Obteniendo datos para Thomas Lemar
# Obteniendo datos para Gelson Martins
# Obteniendo datos para Marcus Rashford
# Obteniendo datos para Paulo Dybala
# Obteniendo datos para Ousmane Dembélé
# Obteniendo datos para Marco Asensio
# Obteniendo datos para Coutinho
# Obteniendo datos para Paul Pogba
# Obteniendo datos para Leroy Sané
# Obteniendo datos para Roberto Firmino
# Obteniendo datos para Alexandr Golovin
# Obteniendo datos para Eden Hazard
# Obteniendo datos para Bruno Fernandes
# Obteniendo datos para N'Golo Kanté
# Obteniendo datos para Sadio Mané
# Obteniendo datos para Zlatan Ibrahimović
# Obteniendo datos para Joshua Kimmich
# Obteniendo datos para Anthony Martial
# Obteniendo datos para Giovani Lo Celso
# Obteniendo datos para Sergej Milinković-Savić
# Obteniendo datos para Kevin De Bruyne
# Obteniendo datos para Robert Lewandowski
# Obteniendo datos para Harry Kane
# Obteniendo datos para Christian Eriksen
# Obteniendo datos para Timo Werner
# Obteniendo datos para Paulinho
# Obteniendo datos para Nabil Fekir
# Obteniendo datos para Lautaro Martínez
# Obteniendo datos para Luis Suárez
# Obteniendo datos para Edinson Cavani
# Obteniendo datos para Romelu Lukaku
# Obteniendo datos para Alisson
# Obteniendo datos para Samuel Umtiti
# Obteniendo datos para Youri Tielemans
# Obteniendo datos para Toni Kroos
# Obteniendo datos para Raheem Sterling
# Obteniendo datos para Dele Alli
# Obteniendo datos para Djibril Sidibé
# Obteniendo datos para Mauro Icardi
# Obteniendo datos para Corentin Tolisso
# Obteniendo datos para Clément Lenglet
# Obteniendo datos para Cristian Pavón
# Obteniendo datos para Riqui Puig
# Obteniendo datos para De Gea
# Obteniendo datos para Gonzalo Higuaín
# Obteniendo datos para Raphaël Varane
# Obteniendo datos para Marco Reus
# Obteniendo datos para Saúl
# Obteniendo datos para Michy Batshuayi
# Obteniendo datos para Benjamin Mendy
# Obteniendo datos para Takefusa Kubo
# Obteniendo datos para Thomas Müller
# Obteniendo datos para Alex Oxlade-Chamberlain
# Obteniendo datos para Piotr Zieliński
# Obteniendo datos para Benjamin Pavard
# Obteniendo datos para Ezequiel Barco
# Obteniendo datos para Thiago
# Obteniendo datos para Koke
# Obteniendo datos para Fabinho
# Obteniendo datos para William Carvalho
# Obteniendo datos para Malcom
# Obteniendo datos para Xherdan Shaqiri
# Obteniendo datos para Olivier Giroud
# Obteniendo datos para Eric Dier
# Obteniendo datos para Kaká
# Obteniendo datos para Max Meyer
# Obteniendo datos para Diogo Dalot
# Obteniendo datos para James Rodríguez
# Obteniendo datos para Dries Mertens
# Obteniendo datos para Iniesta
# Obteniendo datos para Marquinhos
# Obteniendo datos para Alexandre Lacazette
# Obteniendo datos para Kingsley Coman
# Obteniendo datos para Wayne Rooney
# Obteniendo datos para David Silva
# Obteniendo datos para Mesut Özil
# Obteniendo datos para Radja Nainggolan
# Obteniendo datos para Heung Min Son
# Obteniendo datos para Lionel Messi
# Obteniendo datos para Cristiano Ronaldo
# Obteniendo datos para Neymar
# Obteniendo datos para Luis Suárez
# Obteniendo datos para Manuel Neuer
# Obteniendo datos para De Gea
# Obteniendo datos para Kevin De Bruyne
# Obteniendo datos para Robert Lewandowski
# Obteniendo datos para Eden Hazard
# Obteniendo datos para Toni Kroos
# Obteniendo datos para Mats Hummels
# Obteniendo datos para Gonzalo Higuaín
# Obteniendo datos para Sergio Ramos
# Obteniendo datos para Paulo Dybala
# Obteniendo datos para Thibaut Courtois
# Obteniendo datos para Luka Modrić
# Obteniendo datos para David Silva
# Obteniendo datos para Sergio Agüero
# Obteniendo datos para N'Golo Kanté
# Obteniendo datos para Harry Kane
# Obteniendo datos para Paul Pogba
# Obteniendo datos para Antoine Griezmann
# Obteniendo datos para Christian Eriksen
# Obteniendo datos para Thiago
# Obteniendo datos para Diego Godín
# Obteniendo datos para Edinson Cavani
# Obteniendo datos para Hugo Lloris
# Obteniendo datos para Mohamed Salah
# Obteniendo datos para Mauro Icardi
# Obteniendo datos para James Rodríguez
# Obteniendo datos para Marc-André ter Stegen
# Obteniendo datos para Sergio Busquets
# Obteniendo datos para Jordi Alba
# Obteniendo datos para Coutinho
# Obteniendo datos para Jérôme Boateng
# Obteniendo datos para Marcelo
# Obteniendo datos para Mesut Özil
# Obteniendo datos para Dries Mertens
# Obteniendo datos para Thiago Silva
# Obteniendo datos para Piqué
# Obteniendo datos para Iniesta
# Obteniendo datos para Casemiro
# Obteniendo datos para Isco
# Obteniendo datos para Romelu Lukaku
# Obteniendo datos para Alex Sandro
# Obteniendo datos para Thomas Müller
# Obteniendo datos para Azpilicueta
# Obteniendo datos para Radja Nainggolan
# Obteniendo datos para Jan Vertonghen
# Obteniendo datos para Ivan Rakitić
# Obteniendo datos para Filipe Luís
# Obteniendo datos para Zlatan Ibrahimović
# Obteniendo datos para Leroy Sané
# Obteniendo datos para Ederson
# Obteniendo datos para Yannick Carrasco
# Obteniendo datos para Raheem Sterling
# Obteniendo datos para Roberto Firmino
# Obteniendo datos para Raphaël Varane
# Obteniendo datos para Kalidou Koulibaly
# Obteniendo datos para Koke
# Obteniendo datos para Keylor Navas
# Obteniendo datos para Bernd Leno
# Obteniendo datos para Nicolás Otamendi
# Obteniendo datos para Nemanja Matić
# Obteniendo datos para Marco Reus
# Obteniendo datos para İlkay Gündoğan
# Obteniendo datos para Toby Alderweireld
# Obteniendo datos para Ivan Perišić
# Obteniendo datos para Diego Costa
# Obteniendo datos para Medhi Benatia
# Obteniendo datos para Blaise Matuidi
# Obteniendo datos para Miranda
# Obteniendo datos para Falcao
# Obteniendo datos para Karim Benzema
# Obteniendo datos para Cesc Fàbregas
# Obteniendo datos para Franck Ribéry
# Obteniendo datos para Vincent Kompany
# Obteniendo datos para Fernandinho
# Obteniendo datos para Pepe
# Obteniendo datos para Kylian Mbappé
# Obteniendo datos para Marco Asensio
# Obteniendo datos para Bernardo Silva
# Obteniendo datos para Nabil Fekir
# Obteniendo datos para Alisson
# Obteniendo datos para Joshua Kimmich
# Obteniendo datos para Niklas Süle
# Obteniendo datos para Dele Alli
# Obteniendo datos para Fabinho
# Obteniendo datos para Sadio Mané
# Obteniendo datos para Saúl
# Obteniendo datos para Marquinhos
# Obteniendo datos para Samuel Umtiti
# Obteniendo datos para Carvajal
# Obteniendo datos para Julian Draxler
# Obteniendo datos para Morata
# Obteniendo datos para Timo Horn
# Obteniendo datos para Heung Min Son
# Obteniendo datos para Anthony Lopes
# Obteniendo datos para Alexandre Lacazette
# Obteniendo datos para Iago Aspas
# Obteniendo datos para Danijel Subašić
# Obteniendo datos para Kamil Glik
# Obteniendo datos para Douglas Costa
# Obteniendo datos para Parejo
# Obteniendo datos para Kyle Walker
# Obteniendo datos para Wojciech Szczęsny
# Obteniendo datos para Ángel Di María
# Obteniendo datos para Willian
# Obteniendo datos para David Luiz
# Obteniendo datos para Sami Khedira
# Obteniendo datos para Sergio Asenjo
# Obteniendo datos para Javi Martínez
# Obteniendo datos para Dimitri Payet
# Obteniendo datos para Jonas
# Obteniendo datos para Naldo
# Obteniendo datos para Stéphane Ruffier
# Obteniendo datos para Moussa Dembélé
# Obteniendo datos para Alejandro Gómez
# Obteniendo datos para Aduriz
# Obteniendo datos para Ousmane Dembélé
# Obteniendo datos para Gabriel Jesus
# Obteniendo datos para Sergej Milinković-Savić
# Obteniendo datos para José María Giménez
# Obteniendo datos para Thomas Lemar
# Obteniendo datos para Aymeric Laporte
# Obteniendo datos para Timo Werner
# Obteniendo datos para Anthony Martial
# Obteniendo datos para Leon Goretzka
# Obteniendo datos para William Carvalho
# Obteniendo datos para Florian Thauvin
# Obteniendo datos para Danilo Pereira
# Obteniendo datos para Vitolo
# Obteniendo datos para Pizzi
# Obteniendo datos para Oliver Baumann
# Obteniendo datos para Juan Cuadrado
# Obteniendo datos para Mario Götze
# Obteniendo datos para Shkodran Mustafi
# Obteniendo datos para Ander Herrera
# Obteniendo datos para Javier Pastore
# Obteniendo datos para Pedro
# Obteniendo datos para Shinji Kagawa
# Obteniendo datos para Oscar
# Obteniendo datos para Paulinho
# Obteniendo datos para Steven N'Zonzi
# Obteniendo datos para José Callejón
# Obteniendo datos para Giuliano
# Obteniendo datos para Mario Mandžukić
# Obteniendo datos para Federico Fazio
# Obteniendo datos para Benedikt Höwedes
# Obteniendo datos para Ralf Fährmann
# Obteniendo datos para Éver Banega
# Obteniendo datos para Juan Mata
# Obteniendo datos para Rui Patrício
# Obteniendo datos para Lars Bender
# Obteniendo datos para Łukasz Piszczek
# Obteniendo datos para Ezequiel Garay
# Obteniendo datos para Laurent Koscielny
# Obteniendo datos para Raúl Albiol
# Obteniendo datos para Dani Alves
# Obteniendo datos para Javier Mascherano
# Obteniendo datos para Pepe Reina
# Obteniendo datos para Quaresma
# Obteniendo datos para Gelson Martins
# Obteniendo datos para Malcom
# Obteniendo datos para Davinson Sánchez
# Obteniendo datos para Corentin Tolisso
# Obteniendo datos para Gerónimo Rulli
# Obteniendo datos para Andreas Christensen
# Obteniendo datos para Kingsley Coman
# Obteniendo datos para Jonathan Tah
# Obteniendo datos para Alex Telles
# Obteniendo datos para Bruno Fernandes
# Obteniendo datos para Julian Brandt
# Obteniendo datos para André Gomes
# Obteniendo datos para Adrien Rabiot
# Obteniendo datos para Jamie Vardy
# Obteniendo datos para Lucas Vázquez
# Obteniendo datos para Emil Forsberg
# Obteniendo datos para Felipe
# Obteniendo datos para Carlos Bacca
# Obteniendo datos para Mateo Kovačić
# Obteniendo datos para Kepa
# Obteniendo datos para Manu Trigueros
# Obteniendo datos para Iñigo Martínez
# Obteniendo datos para Thorgan Hazard
# Obteniendo datos para Suso
# Obteniendo datos para Lucas
# Obteniendo datos para Sergi Roberto
# Obteniendo datos para Granit Xhaka
# Obteniendo datos para Willian José
# Obteniendo datos para Idrissa Gueye
# Obteniendo datos para Víctor Ruiz
# Obteniendo datos para Xherdan Shaqiri
# Obteniendo datos para Marcos Alonso
# Obteniendo datos para Taison
# Obteniendo datos para Luiz Gustavo
# Obteniendo datos para Adrien Silva
# Obteniendo datos para Bruno
# Obteniendo datos para Max Kruse
# Obteniendo datos para Ljubomir Fejsa
# Obteniendo datos para Vedran Ćorluka
# Obteniendo datos para Adam Lallana
# Obteniendo datos para Olivier Giroud
# Obteniendo datos para Branislav Ivanović
# Obteniendo datos para Adán
# Obteniendo datos para Yann Sommer
# Obteniendo datos para Axel Witsel
# Obteniendo datos para Kévin Gameiro
# Obteniendo datos para Lucas Leiva
# Obteniendo datos para Gary Cahill
# Obteniendo datos para Steve Mandanda
# Obteniendo datos para Kasper Schmeichel
# Obteniendo datos para João Moutinho
# Obteniendo datos para Borja Valero
# Obteniendo datos para Lucas Biglia
# Obteniendo datos para Juanfran
# Obteniendo datos para Diego López
# Obteniendo datos para David Villa
# Obteniendo datos para Casillas
# Obteniendo datos para Marcus Rashford
# Obteniendo datos para Nélson Semedo
# Obteniendo datos para Pau López
# Obteniendo datos para Andrej Kramarić
# Obteniendo datos para Williams
# Obteniendo datos para Dani García
# Obteniendo datos para Keita Baldé
# Obteniendo datos para João Mário
# Obteniendo datos para Anderson Talisca
# Obteniendo datos para Morgan Sanson
# Obteniendo datos para Ricardo Pereira
# Obteniendo datos para Fred
# Obteniendo datos para Hakim Ziyech
# Obteniendo datos para Jesse Lingard
# Obteniendo datos para Sergio Rico
# Obteniendo datos para Antonio Rüdiger
# Obteniendo datos para Matija Nastasić
# Obteniendo datos para Michy Batshuayi
# Obteniendo datos para Jack Butland
# Obteniendo datos para Karim Bellarabi
# Obteniendo datos para Deulofeu
# Obteniendo datos para Thomas Meunier
# Obteniendo datos para Eric Dier
# Obteniendo datos para Felipe Anderson
# Obteniendo datos para Geoffrey Kondogbia
# Obteniendo datos para Rafinha
# Obteniendo datos para Gabriel Paulista
# Obteniendo datos para Nacho Fernández
# Obteniendo datos para Kevin Volland
# Obteniendo datos para Allan
# Obteniendo datos para Wissam Ben Yedder
# Obteniendo datos para Alex Oxlade-Chamberlain
# Obteniendo datos para Luis Alberto
# Obteniendo datos para Rodrigo
# Obteniendo datos para Bartra
# Obteniendo datos para Sebastián Coates
# Obteniendo datos para Neto
# Obteniendo datos para Daniel Didavi
# Obteniendo datos para Younès Belhanda
# Obteniendo datos para Mário Fernandes
# Obteniendo datos para Jesús Corona
# Obteniendo datos para Illarramendi
# Obteniendo datos para Nathaniel Clyne
# Obteniendo datos para Chris Smalling
# Obteniendo datos para Iborra
# Obteniendo datos para Jack Wilshere
# Obteniendo datos para Sebastian Rudy
# Obteniendo datos para Roman Bürki
# Obteniendo datos para Manuel Lanzini
# Obteniendo datos para Camacho
# Obteniendo datos para Fedor Smolov
# Obteniendo datos para Lars Stindl
# Obteniendo datos para Aleksandar Kolarov
# Obteniendo datos para Gylfi Sigurðsson
# Obteniendo datos para Diego Perotti
# Obteniendo datos para Jordan Henderson
# Obteniendo datos para Adil Rami
# Obteniendo datos para Fernando Muslera
# Obteniendo datos para Marcelo
# Obteniendo datos para Beñat
# Obteniendo datos para Mathieu Valbuena
# Obteniendo datos para Marcano
# Obteniendo datos para Daniel Wass
# Obteniendo datos para Andrés Guardado
# Obteniendo datos para Daniel Sturridge
# Obteniendo datos para Danny Rose
# Obteniendo datos para Carlos Vela
# Obteniendo datos para Tom Heaton
# Obteniendo datos para Loïc Perrin
# Obteniendo datos para Manuel Fernandes
# Obteniendo datos para André-Pierre Gignac
# Obteniendo datos para Mario Gómez
# Obteniendo datos para Gabi
# Obteniendo datos para Raffael
# Obteniendo datos para Nani
# Obteniendo datos para Bastian Schweinsteiger
# Obteniendo datos para Rubén Castro
# Obteniendo datos para Jérémy Mathieu
# Obteniendo datos para Onyinye Ndidi
# Obteniendo datos para Presnel Kimpembe
# Obteniendo datos para Gonçalo Guedes
# Obteniendo datos para Marcos Acuña
# Obteniendo datos para Julian Weigl
# Obteniendo datos para Raúl
# Obteniendo datos para Yerry Mina
# Obteniendo datos para Clément Lenglet
# Obteniendo datos para Tiémoué Bakayoko
# Obteniendo datos para Marcelo Brozović
# Obteniendo datos para Jemerson
# Obteniendo datos para Ángel Correa
# Obteniendo datos para Kerem Demirbay
# Obteniendo datos para Bruma
# Obteniendo datos para Samu Castillejo
# Obteniendo datos para Piotr Zieliński
# Obteniendo datos para Grimaldo
# Obteniendo datos para Raphaël Guerreiro
# Obteniendo datos para Jonas Hector
# Obteniendo datos para Emre Can
# Obteniendo datos para Abdoulaye Doucouré
# Obteniendo datos para Gerard Moreno
# Obteniendo datos para Michael Keane
# Obteniendo datos para Leandro Paredes
# Obteniendo datos para Alassane Pléa
# Obteniendo datos para Leo Baptistao
# Obteniendo datos para Bernard
# Obteniendo datos para Denis Suárez
# Obteniendo datos para Jordan Pickford
# Obteniendo datos para Willi Orban
# Obteniendo datos para Roque Mesa
# Obteniendo datos para Christoph Kramer
# Obteniendo datos para Šime Vrsaljko
# Obteniendo datos para Loris Karius
# Obteniendo datos para Héctor Bellerín
# Obteniendo datos para John Stones
# Obteniendo datos para Jannik Vestergaard
# Obteniendo datos para Salif Sané
# Obteniendo datos para Marcos Rojo
# Obteniendo datos para Jeison Murillo
# Obteniendo datos para Benjamin Lecomte
# Obteniendo datos para Mark Uth
# Obteniendo datos para Lucas Pérez
# Obteniendo datos para Ross Barkley
# Obteniendo datos para Luis Muriel
# Obteniendo datos para Pablo Sarabia
# Obteniendo datos para Josuha Guilavogui
# Obteniendo datos para Dejan Lovren
# Obteniendo datos para Phil Jones
# Obteniendo datos para Hugo Mallo
# Obteniendo datos para Ricardo Rodríguez
# Obteniendo datos para Alphonse Areola
# Obteniendo datos para Koen Casteels
# Obteniendo datos para Mario Gaspar
# Obteniendo datos para Kevin Vogt
# Obteniendo datos para Alexandr Kokorin
# Obteniendo datos para Maicon
# Obteniendo datos para Eduardo Salvio
# Obteniendo datos para Adem Ljajić
# Obteniendo datos para Iago Falqué
# Obteniendo datos para De Marcos
# Obteniendo datos para Ben Mee
# Obteniendo datos para Susaeta
# Obteniendo datos para Francis Coquelin
# Obteniendo datos para Kevin Trapp
# Obteniendo datos para Alan Dzagoev
# Obteniendo datos para Mateo Musacchio
# Obteniendo datos para Kieran Trippier
# Obteniendo datos para Danny Drinkwater
# Obteniendo datos para Pablo Piatti
# Obteniendo datos para Mamadou Sakho
# Obteniendo datos para Sidnei
# Obteniendo datos para Fabricio
# Obteniendo datos para Kiko Casilla
# Obteniendo datos para Nacho Monreal
# Obteniendo datos para Sven Bender
# Obteniendo datos para Morgan Schneiderlin
# Obteniendo datos para Marcus Berg
# Obteniendo datos para Pontus Wernbloom
# Obteniendo datos para Ignacio Piatti
# Obteniendo datos para Pedro León
# Obteniendo datos para Simon Mignolet
# Obteniendo datos para Sergio Romero
# Obteniendo datos para Victor Moses
# Obteniendo datos para Diego Valeri
# Obteniendo datos para Raúl García
# Obteniendo datos para Erik Lamela
# Obteniendo datos para Renato Augusto
# Obteniendo datos para Jardel
# Obteniendo datos para Gonzalo Castro
# Obteniendo datos para Gustavo Cabral
# Obteniendo datos para Łukasz Fabiański
# Obteniendo datos para Lassana Diarra
# Obteniendo datos para Leighton Baines
# Obteniendo datos para Bafétimbi Gomis
# Obteniendo datos para Dante
# Obteniendo datos para Benoît Costil
# Obteniendo datos para Andreas Granqvist
# Obteniendo datos para Héctor Herrera
# Obteniendo datos para Igor Akinfeev
# Obteniendo datos para Igor Denisov
# Obteniendo datos para Santi Cazorla
# Obteniendo datos para Xabi Prieto
# Obteniendo datos para Fernando Belluschi
# Obteniendo datos para Gonzalo Rodríguez
# Obteniendo datos para Kaká
# Obteniendo datos para James Milner
# Obteniendo datos para Moyá
# Obteniendo datos para Stephan Lichtsteiner
# Obteniendo datos para Wayne Rooney
# Obteniendo datos para Fernando Torres
# Obteniendo datos para Raphinha
# Obteniendo datos para Oyarzabal
# Obteniendo datos para Andrey Lunev
# Obteniendo datos para Alexandr Golovin
# Obteniendo datos para Martín Campaña
# Obteniendo datos para Franco Cervi
# Obteniendo datos para Hirving Lozano
# Obteniendo datos para Lucas Hernández
# Obteniendo datos para Matias Vecino
# Obteniendo datos para Diego Carlos
# Obteniendo datos para Mahmoud Dahoud
# Obteniendo datos para Rafa
# Obteniendo datos para Morales
# Obteniendo datos para Youri Tielemans
# Obteniendo datos para Darío Benedetto
# Obteniendo datos para Iván Marcone
# Obteniendo datos para Stanislav Kritsyuk
# Obteniendo datos para Rony Lopes
# Obteniendo datos para Max Meyer
# Obteniendo datos para Gayà
# Obteniendo datos para Nicolás Tagliafico
# Obteniendo datos para João Cancelo
# Obteniendo datos para Óliver Torres
# Obteniendo datos para Andreas Pereira
# Obteniendo datos para Adnan Januzaj
# Obteniendo datos para Matthias Ginter
# Obteniendo datos para Maximilian Arnold
# Obteniendo datos para Oleg Shatov
# Obteniendo datos para Serge Gnabry
# Obteniendo datos para Arkadiusz Milik
# Obteniendo datos para Benjamin Mendy
# Obteniendo datos para Valère Germain
# Obteniendo datos para Harry Maguire
# Obteniendo datos para Álvaro
# Obteniendo datos para James Tarkowski
# Obteniendo datos para Sergi Darder
# Obteniendo datos para Fernando
# Obteniendo datos para Diego Demme
# Obteniendo datos para Layvin Kurzawa
# Obteniendo datos para Gastón Ramírez
# Obteniendo datos para David López
# Obteniendo datos para Milan Badelj
# Obteniendo datos para Djibril Sidibé
# Obteniendo datos para Lucas Digne
# Obteniendo datos para Paco Alcácer
# Obteniendo datos para Campaña
# Obteniendo datos para Nolito
# Obteniendo datos para Dušan Tadić
# Obteniendo datos para Danilo
# Obteniendo datos para Domagoj Vida
# Obteniendo datos para Grzegorz Krychowiak
# Obteniendo datos para Enzo Pérez
# Obteniendo datos para Sergi Enrich
# Obteniendo datos para Germán Pezzella
# Obteniendo datos para Jaume Costa
# Obteniendo datos para Herrerín
# Obteniendo datos para André Schürrle
# Obteniendo datos para Roberto Pereyra
# Obteniendo datos para Escudero
# Obteniendo datos para Michail Antonio
# Obteniendo datos para Marwin Hitz
# Obteniendo datos para Muniain
# Obteniendo datos para Iturraspe
# Obteniendo datos para Benjamin Hübner
# Obteniendo datos para Souza
# Obteniendo datos para Daniel Carriço
# Obteniendo datos para Gustavo Bou
# Obteniendo datos para Marcel Schmelzer
# Obteniendo datos para Igor Smolnikov
# Obteniendo datos para Yann M'Vila
# Obteniendo datos para Keisuke Honda
# Obteniendo datos para Sven Ulreich
# Obteniendo datos para Cristhian Stuani
# Obteniendo datos para Marco Fabián
# Obteniendo datos para Ron-Robert Zieler
# Obteniendo datos para Danny Welbeck
# Obteniendo datos para Nikola Kalinić
# Obteniendo datos para Mikel San José
# Obteniendo datos para Mariano
# Obteniendo datos para Fernando
# Obteniendo datos para Christian Benteke
# Obteniendo datos para Sandro Wagner
# Obteniendo datos para Gabriel Mercado
# Obteniendo datos para Fabian Delph
# Obteniendo datos para Nordin Amrabat
# Obteniendo datos para Antunes
# Obteniendo datos para Javier Hernández
# Obteniendo datos para Serdar Tasci
# Obteniendo datos para Marouane Fellaini
# Obteniendo datos para Héctor Moreno
# Obteniendo datos para Cristian Ansaldi
# Obteniendo datos para David Zurutuza
# Obteniendo datos para Kevin Mirallas
# Obteniendo datos para Fábio Coentrão
# Obteniendo datos para Steven Defour
# Obteniendo datos para Ryan Bertrand
# Obteniendo datos para Theo Walcott
# Obteniendo datos para Karim El Ahmadi
# Obteniendo datos para Hatem Ben Arfa
# Obteniendo datos para David Abraham
# Obteniendo datos para Jurado
# Obteniendo datos para Jefferson Farfán
# Obteniendo datos para Ashley Young
# Obteniendo datos para Vasiliy Berezutskiy
# Obteniendo datos para Alexandr Samedov
# Obteniendo datos para Javi Fuego
# Obteniendo datos para Negredo
# Obteniendo datos para Willy Caballero
# Obteniendo datos para Daniel Baier
# Obteniendo datos para René Adler
# Obteniendo datos para Cédric Carrasso
# Obteniendo datos para Phil Jagielka
# Obteniendo datos para Joaquín
# Obteniendo datos para Maximiliano Gómez
# Obteniendo datos para David Neres
# Obteniendo datos para Carlos Soler
# Obteniendo datos para Odriozola
# Obteniendo datos para Amine Harit
# Obteniendo datos para Yeray
# Obteniendo datos para Soares
# Obteniendo datos para Lucas Tousart
# Obteniendo datos para Pablo Fornals
# Obteniendo datos para Marcos Díaz
# Obteniendo datos para Marcos Llorente
# Obteniendo datos para Nadiem Amiri
# Obteniendo datos para Vallejo
# Obteniendo datos para Nemanja Radoja
# Obteniendo datos para Diogo Jota
# Obteniendo datos para Rúben Neves
# Obteniendo datos para Lucas Torreira
# Obteniendo datos para Valentin Rongier
# Obteniendo datos para Dani Ceballos
# Obteniendo datos para Victor Lindelöf
# Obteniendo datos para Andrija Živković
# Obteniendo datos para José Izquierdo
# Obteniendo datos para Gonzalo Escalante
# Obteniendo datos para Giovanni Simeone
# Obteniendo datos para Maximilian Philipp
# Obteniendo datos para Capa
# Obteniendo datos para Alireza Jahanbakhsh
# Obteniendo datos para Nikola Maksimović
# Obteniendo datos para Lucas Alario
# Obteniendo datos para Duván Zapata
# Obteniendo datos para Emiliano Rigoni
# Obteniendo datos para Franco Armani
# Obteniendo datos para Yimmi Chará
# Obteniendo datos para Alexandr Selikhov
# Obteniendo datos para Diego Laxalt
# Obteniendo datos para Roman Zobnin
# Obteniendo datos para Diego Rolán
# Obteniendo datos para Niklas Stark
# Obteniendo datos para Wylan Cyprien
# Obteniendo datos para Diego Llorente
# Obteniendo datos para Avilés Hurtado
# Obteniendo datos para Philipp Max
# Obteniendo datos para Pedro Santos
# Obteniendo datos para Marcel Halstenberg
# Obteniendo datos para Jonny
# Obteniendo datos para Alexander Szymanowski
# Obteniendo datos para Pacheco
# Obteniendo datos para Tiago Volpi
# Obteniendo datos para Filip Kostić
# Obteniendo datos para Matheus
# Obteniendo datos para Guido Pizarro
# Obteniendo datos para Luciano Vietto
# Obteniendo datos para Mitchell Weiser
# Obteniendo datos para Luka Milivojević
# Obteniendo datos para Luke Shaw
# Obteniendo datos para Zouhair Feddal
# Obteniendo datos para Sébastien Haller
# Obteniendo datos para Lucas Castro
# Obteniendo datos para Takashi Inui
# Obteniendo datos para Portu
# Obteniendo datos para Emiliano Sala
# Obteniendo datos para Mário Rui
# Obteniendo datos para Kurt Zouma
# Obteniendo datos para Santiago Arias
# Obteniendo datos para Baptiste Reynet
# Obteniendo datos para Eric Botteghin
# Obteniendo datos para Nick Pope
# Obteniendo datos para Joãozinho
# Obteniendo datos para Jamaal Lascelles
# Obteniendo datos para Leonardo Bittencourt
# Obteniendo datos para Jordan Veretout
# Obteniendo datos para Ismaily
# Obteniendo datos para Cédric
# Obteniendo datos para Agustín Marchesín
# Obteniendo datos para Juan Jesus
# Obteniendo datos para Nacer Chadli
# Obteniendo datos para Cristian Tello
# Obteniendo datos para Hans Vanaken
# Obteniendo datos para Matthew Lowton
# Obteniendo datos para John Guidetti
# Obteniendo datos para Oriol Romeu
# Obteniendo datos para Mathew Ryan
# Obteniendo datos para Kara Mbodji
# Obteniendo datos para Benjamin Stambouli
# Obteniendo datos para Rogelio Funes Mori
# Obteniendo datos para Florian Lejeune
# Obteniendo datos para Nicolás Lodeiro
# Obteniendo datos para Teófilo Gutiérrez
# Obteniendo datos para Alfreð Finnbogason
# Obteniendo datos para Aaron Mooy
# Obteniendo datos para Andros Townsend
# Obteniendo datos para Adrián
# Obteniendo datos para Wahbi Khazri
# Obteniendo datos para Montoya
# Obteniendo datos para André Almeida
# Obteniendo datos para Thomas Delaney
# Obteniendo datos para Holger Badstuber
# Obteniendo datos para Marvin Plattenhardt
# Obteniendo datos para Jóhann Berg Guðmundsson
# Obteniendo datos para Celso Borges
# Obteniendo datos para Pascal Groß
# Obteniendo datos para Eliaquim Mangala
# Obteniendo datos para Etxeita
# Obteniendo datos para Canales
# Obteniendo datos para Balenziaga
# Obteniendo datos para Rafael
# Obteniendo datos para Víctor Vázquez
# Obteniendo datos para Victor Sánchez
# Obteniendo datos para Bastian Oczipka
# Obteniendo datos para Jonathas
# Obteniendo datos para Jonjo Shelvey
# Obteniendo datos para Miguel Lopes
# Obteniendo datos para Lautaro Acosta
# Obteniendo datos para Pavel Mamaev
# Obteniendo datos para Ganso
# Obteniendo datos para Rafael Tolói
# Obteniendo datos para Ivan Radovanović
# Obteniendo datos para Elías Hernández
# Obteniendo datos para Romain Alessandrini
# Obteniendo datos para Michael Lang
# Obteniendo datos para Lucas Pratto
# Obteniendo datos para Romain Thomas
# Obteniendo datos para Mehdi Carcela-González
# Obteniendo datos para Nicolai Müller
# Obteniendo datos para Roberto
# Obteniendo datos para Nils Petersen
# Obteniendo datos para Neven Subotić
# Obteniendo datos para Yuri Berchiche
# Obteniendo datos para Maximiliano Pereira
# Obteniendo datos para Martín Cáceres
# Obteniendo datos para Luiz Adriano
# Obteniendo datos para Guilherme
# Obteniendo datos para Damien Da Silva
# Obteniendo datos para Simon Kjær
# Obteniendo datos para Loïc Rémy
# Obteniendo datos para Miguel Layún
# Obteniendo datos para Thomas Mangani
# Obteniendo datos para Granero
# Obteniendo datos para Cristian Zapata
# Obteniendo datos para Nahuel Guzmán
# Obteniendo datos para David Ospina
# Obteniendo datos para Vadis Odjidja-Ofoe
# Obteniendo datos para Adrián
# Obteniendo datos para James Tomkins
# Obteniendo datos para Coke
# Obteniendo datos para Moussa Sow
# Obteniendo datos para José Fonte
# Obteniendo datos para Jonathan dos Santos
# Obteniendo datos para Giovani dos Santos
# Obteniendo datos para Jack Cork
# Obteniendo datos para Ryan Shawcross
# Obteniendo datos para Rafinha
# Obteniendo datos para Yohan Cabaye
# Obteniendo datos para Dušan Basta
# Obteniendo datos para Fernando Gago
# Obteniendo datos para Nicolás Pareja
# Obteniendo datos para Adriano
# Obteniendo datos para Charles
# Obteniendo datos para Sergio
# Obteniendo datos para Bacary Sagna
# Obteniendo datos para Ben Foster
# Obteniendo datos para Javi García
# Obteniendo datos para Christian Gentner
# Obteniendo datos para Thomas Vermaelen
# Obteniendo datos para Pablo Batalla
# Obteniendo datos para Rodrigo Palacio
# Obteniendo datos para José Sand
# Obteniendo datos para Joe Hart
# Obteniendo datos para Lukas Podolski
# Obteniendo datos para Luisão
# Obteniendo datos para Soldado
# Obteniendo datos para Jesús Navas
# Obteniendo datos para José Sosa
# Obteniendo datos para Carlos Tévez
# Obteniendo datos para Marcelo Barovero
# Obteniendo datos para Lisandro López
# Obteniendo datos para Vincent Enyeama
# Obteniendo datos para Leonardo Ponzio
# Obteniendo datos para Vágner Love
# Obteniendo datos para Gomes
# Obteniendo datos para Jimmy Briand
# Obteniendo datos para Reyes
# Obteniendo datos para Jermain Defoe
# Obteniendo datos para Aarón Martín
# Obteniendo datos para Kai Havertz
# Obteniendo datos para Tanguy Ndombele
# Obteniendo datos para Rodri
# Obteniendo datos para Alban Lafont
# Obteniendo datos para Filip Krovinović
# Obteniendo datos para Formosandrinho
# Obteniendo datos para Sidney Pessinho
# Obteniendo datos para Everticinho
# Obteniendo datos para Louri Beretta
# Obteniendo datos para Claudio Coíntra
# Obteniendo datos para Ronaldo Esler
# Obteniendo datos para Gazzolisco
# Obteniendo datos para Raphaelito Anjos
# Obteniendo datos para Denis Zakaria
# Obteniendo datos para André Silva
# Obteniendo datos para Benjamin Pavard
# Obteniendo datos para Gonzalo Martínez
# Obteniendo datos para Fabián
# Obteniendo datos para Giovani Lo Celso
# Obteniendo datos para Vincent Koziello
# Obteniendo datos para Fábio Martins
# Obteniendo datos para André Simões
# Obteniendo datos para Daler Kuzyaev
# Obteniendo datos para Jorge Meré
# Obteniendo datos para Emanuel Mammana
# Obteniendo datos para Germán Conti
# Obteniendo datos para Yoan Cardinale
# Obteniendo datos para Lovre Kalinić
# Obteniendo datos para Rodrigo Battaglia
# Obteniendo datos para Jonathan Calleri
# Obteniendo datos para Pedro Henrique
# Obteniendo datos para Federico Cartabia
# Obteniendo datos para Maximiliano Meza
# Obteniendo datos para Léo Dubois
# Obteniendo datos para Wendell
# Obteniendo datos para Wallace
# Obteniendo datos para Allan Saint-Maximin
# Obteniendo datos para Alen Halilović
# Obteniendo datos para Joaquín Correa
# Obteniendo datos para Pablo Pérez
# Obteniendo datos para Lisandro López
# Obteniendo datos para Matías Kranevitter
# Obteniendo datos para Carlos Izquierdoz
# Obteniendo datos para Wilmar Barrios
# Obteniendo datos para Daniel Torres
# Obteniendo datos para Alexey Miranchuk
# Obteniendo datos para Alan Ruiz
# Obteniendo datos para Ricardo Horta
# Obteniendo datos para Facundo Ferreyra
# Obteniendo datos para Divock Origi
# Obteniendo datos para Mohamed Elneny
# Obteniendo datos para Santi Mina
# Obteniendo datos para Leander Dendoncker
# Obteniendo datos para José Sá
# Obteniendo datos para Ricardo Esgaio
# Obteniendo datos para Dominik Kohr
# Obteniendo datos para Pione Sisto
# Obteniendo datos para Sofiane Boufal
# Obteniendo datos para Rubén Blanco
# Obteniendo datos para Carles Gil
# Obteniendo datos para Rodolfo Pizarro
# Obteniendo datos para Paulo Oliveira
# Obteniendo datos para Juan Fernando Quintero
# Obteniendo datos para Otávio
# Obteniendo datos para Jonas Hofmann
# Obteniendo datos para Jozabed
# Obteniendo datos para Fabian Schär
# Obteniendo datos para José Juan Vázquez
# Obteniendo datos para Omar Mascarell
# Obteniendo datos para Hiroki Sakai
# Obteniendo datos para Yussuf Poulsen
# Obteniendo datos para Marçal
# Obteniendo datos para Jordan Lukaku
# Obteniendo datos para Bigas
# Obteniendo datos para Dominique Heintz
# Obteniendo datos para Luís Hernández
# Obteniendo datos para James Ward-Prowse
# Obteniendo datos para Alberto Moreno
# Obteniendo datos para Marcelo
# Obteniendo datos para Bernat
# Obteniendo datos para Raúl Jiménez
# Obteniendo datos para Joel Campbell
# Obteniendo datos para Mauricio Pereyra
# Obteniendo datos para M'Baye Niang
# Obteniendo datos para Adrien Trebel
# Obteniendo datos para André Carrillo
# Obteniendo datos para Rodrigo Moledo
# Obteniendo datos para Jérôme Roussillon
# Obteniendo datos para Federico Fernández
# Obteniendo datos para Recio
# Obteniendo datos para Paul-Georges Ntep
# Obteniendo datos para Nicolas De Préville
# Obteniendo datos para Bruno
# Obteniendo datos para Sebastian Rode
# Obteniendo datos para Nicolás Blandi
# Obteniendo datos para Pedro Obiang
# Obteniendo datos para Vicente Gómez
# Obteniendo datos para Nicolai Jørgensen
# Obteniendo datos para Wilson Eduardo
# Obteniendo datos para Ramiro Funes Mori
# Obteniendo datos para Sergi Gómez
# Obteniendo datos para Nicolas Pallois
# Obteniendo datos para Sergio Álvarez
# Obteniendo datos para Sergio León
# Obteniendo datos para Jordi Amat
# Obteniendo datos para Patrick Herrmann
# Obteniendo datos para Juanmi
# Obteniendo datos para Callum Wilson
# Obteniendo datos para Dorlan Pabón
# Obteniendo datos para Charlie Austin
# Obteniendo datos para Borja García
# Obteniendo datos para Shinji Okazaki
# Obteniendo datos para André Pinto
# Obteniendo datos para Nemanja Pejčinović
# Obteniendo datos para Rémy Cabella
# Obteniendo datos para Steve Cook
# Obteniendo datos para Marc Muniesa
# Obteniendo datos para Maxime Le Marchand
# Obteniendo datos para Romain Hamouma
# Obteniendo datos para Carlos Eduardo
# Obteniendo datos para Maxime Lestienne
# Obteniendo datos para Fontàs
# Obteniendo datos para Javier Aquino
# Obteniendo datos para Diego Reyes
# Obteniendo datos para Sébastien Corchia
# Obteniendo datos para Benjamin André
# Obteniendo datos para Yannis Salibur
# Obteniendo datos para Guaita
# Obteniendo datos para Danny Latza
# Obteniendo datos para Marcel Risse
# Obteniendo datos para Caiuby
# Obteniendo datos para Jefferson
# Obteniendo datos para Rafael Carioca
# Obteniendo datos para Artem Dzyuba
# Obteniendo datos para Soslan Dzhanaev
# Obteniendo datos para Viktor Vasin
# Obteniendo datos para Denis Glushakov
# Obteniendo datos para Mame Diouf
# Obteniendo datos para Kieran Gibbs
# Obteniendo datos para Yoel
# Obteniendo datos para Sebastian Langkamp
# Obteniendo datos para Moussa Sissoko
# Obteniendo datos para Fin Bartels
# Obteniendo datos para Troy Deeney
# Obteniendo datos para Carlos Sánchez
# Obteniendo datos para Andy Carroll
# Obteniendo datos para William Vainqueur
# Obteniendo datos para Makoto Hasebe
# Obteniendo datos para Luisinho
# Obteniendo datos para Miguel Veloso
# Obteniendo datos para Vieirinha
# Obteniendo datos para Nabil Dirar
# Obteniendo datos para Demba Ba
# Obteniendo datos para Bojan
# Obteniendo datos para Óscar Trejo
# Obteniendo datos para Ignacio Scocco
# Obteniendo datos para Jay Rodriguez
# Obteniendo datos para Ari
# Obteniendo datos para Federico Higuaín
# Obteniendo datos para Danilo
# Obteniendo datos para Cyril Théréau
# Obteniendo datos para Bradley Wright-Phillips
# Obteniendo datos para Curtis Davies
# Obteniendo datos para Llorente
# Obteniendo datos para Mauro Boselli
# Obteniendo datos para Michael Krohn-Dehli
# Obteniendo datos para Mathieu Debuchy
# Obteniendo datos para Alfredo Talavera
# Obteniendo datos para Guillaume Hoarau
# Obteniendo datos para Alexandr Belenov
# Obteniendo datos para Yoann Gourcuff
# Obteniendo datos para Hilton
# Obteniendo datos para Mauro Zárate
# Obteniendo datos para Darío Cvitanich
# Obteniendo datos para Aaron Lennon
# Obteniendo datos para Gaël Clichy
# Obteniendo datos para Alexey Berezutskiy
# Obteniendo datos para Oscar Wendt
# Obteniendo datos para Jesús Dátolo
# Obteniendo datos para Mariano Barbosa
# Obteniendo datos para Guillermo Ochoa
# Obteniendo datos para Blerim Džemaili
# Obteniendo datos para Sergio García
# Obteniendo datos para Diego Benaglio
# Obteniendo datos para Sergey Ignashevich
# Obteniendo datos para Silvio Proto
# Obteniendo datos para Unai Núñez
# Obteniendo datos para Rúben Dias
# Obteniendo datos para Fabricio Bustos
# Obteniendo datos para Marko Rog
# Obteniendo datos para Henry Onyekuru
# Obteniendo datos para Yu Kobayashi
# Obteniendo datos para Shoya Nakajima
# Obteniendo datos para Federico Ricca
# Obteniendo datos para Santiago Ascacibar
# Obteniendo datos para Richarlison
# Obteniendo datos para Issa Diop
# Obteniendo datos para Lautaro Martínez
# Obteniendo datos para Dênildo Stein
# Obteniendo datos para Ronaldo Cabrais
# Obteniendo datos para David Seijalbo
# Obteniendo datos para Vieirundinho
# Obteniendo datos para Welington Dano
# Obteniendo datos para Nelsildo Reis
# Obteniendo datos para Fred Aníbão
# Obteniendo datos para Gabri Prestão
# Obteniendo datos para Laure Santeiro
# Obteniendo datos para Rosberto Dourado
# Obteniendo datos para Everton Andrão
# Obteniendo datos para Eltildo Correia
# Obteniendo datos para Antônio Chiamuloira
# Obteniendo datos para Pierre Lees-Melou
# Obteniendo datos para Georgiy Dzhikiya
# Obteniendo datos para Gastón Pereiro
# Obteniendo datos para Marko Pjaca
# Obteniendo datos para Dayot Upamecano
# Obteniendo datos para Waldemar Anton
# Obteniendo datos para Costinha
# Obteniendo datos para Gil Dias
# Obteniendo datos para Aminu Umar
# Obteniendo datos para Yoshinori Mutō
# Obteniendo datos para Kasper Dolberg
# Obteniendo datos para Benjamin Henrichs
# Obteniendo datos para Matheus Pereira
# Obteniendo datos para Daniel Podence
# Obteniendo datos para Vitor Hugo
# Obteniendo datos para Marcus Coco
# Obteniendo datos para Ramón Ábila
# Obteniendo datos para Aritz
# Obteniendo datos para Maximilian Eggestein
# Obteniendo datos para Nordi Mukiele
# Obteniendo datos para Abdou Diallo
# Obteniendo datos para Alex Berenguer
# Obteniendo datos para Marius Wolf
# Obteniendo datos para Cristian Pavón
# Obteniendo datos para Danilo
# Obteniendo datos para Mario Pašalić
# Obteniendo datos para Jony
# Obteniendo datos para Otávio
# Obteniendo datos para Breel Embolo
# Obteniendo datos para Lee Jae Sung
# Obteniendo datos para Nico Elvedi
# Obteniendo datos para Sebastián Driussi
# Obteniendo datos para Badou Ndiaye
# Obteniendo datos para Erick Gutiérrez
# Obteniendo datos para Jaume
# Obteniendo datos para Diego Rico
# Obteniendo datos para Munir
# Obteniendo datos para Ante Rebić
# Obteniendo datos para Bruno Varela
# Obteniendo datos para Georges-Kévin Nkoudou
# Obteniendo datos para Jordan Amavi
# Obteniendo datos para Camarasa
# Obteniendo datos para Theo Bongonda
# Obteniendo datos para Sandro
# Obteniendo datos para José Luis Palomino
# Obteniendo datos para Carlos Mané
# Obteniendo datos para Paulinho
# Obteniendo datos para Álvaro García
# Obteniendo datos para Marcelo Goiano
# Obteniendo datos para Yuriy Lodygin
# Obteniendo datos para Silvan Widmer
# Obteniendo datos para Tin Jedvaj
# Obteniendo datos para Aleksandar Mitrović
# Obteniendo datos para Youssouf Sabaly
# Obteniendo datos para Lucas Evangelista
# Obteniendo datos para Walter Benítez
# Obteniendo datos para Rubén Botta
# Obteniendo datos para Martín Benítez
# Obteniendo datos para Diego González
# Obteniendo datos para Alexander Mejía
# Obteniendo datos para Vladimir Hernández
# Obteniendo datos para Felipe Pardo
# Obteniendo datos para Frank Fabra
# Obteniendo datos para Jefferson Lerma
# Obteniendo datos para Sardar Azmoun
# Obteniendo datos para Thiago Mendes
# Obteniendo datos para Alex Iwobi
# Obteniendo datos para Pierre-Emile Højbjerg
# Obteniendo datos para Hernâni
# Obteniendo datos para Óscar Duarte
# Obteniendo datos para Leonel Vangioni
# Obteniendo datos para Iuri Medeiros
# Obteniendo datos para Alexander Djiku
# Obteniendo datos para Pere Pons
# Obteniendo datos para Karol Linetty
# Obteniendo datos para Ricardo Centurión
# Obteniendo datos para Pablo De Blasis
# Obteniendo datos para Ricardo Ferreira
# Obteniendo datos para Ahmed Hegazi
# Obteniendo datos para Renato Steffen
# Obteniendo datos para Bruno Peres
# Obteniendo datos para Sam Larsson
# Obteniendo datos para Guilherme
# Obteniendo datos para Nawaf Al Abed
# Obteniendo datos para Giancarlo González
# Obteniendo datos para Romain Saïss
# Obteniendo datos para Ivan Santini
# Obteniendo datos para Vitinho
# Obteniendo datos para Roger
# Obteniendo datos para Simon Falette
# Obteniendo datos para Will Hughes
# Obteniendo datos para Denis Cheryshev
# Obteniendo datos para Nathaniel Chalobah
# Obteniendo datos para Marko Livaja
# Obteniendo datos para Lucas Ocampos
# Obteniendo datos para Carlos Sánchez
# Obteniendo datos para Niclas Füllkrug
# Obteniendo datos para Sebastián Sosa
# Obteniendo datos para Santiago Gentiletti
# Obteniendo datos para Raúl Ruidíaz
# Obteniendo datos para Rubén Pardo
# Obteniendo datos para Bouna Sarr
# Obteniendo datos para Santiago García
# Obteniendo datos para Luís Neto
# Obteniendo datos para Christophe Kerbrat
# Obteniendo datos para Julian Korb
# Obteniendo datos para Charly Musonda
# Obteniendo datos para Yassin Ayoub
# Obteniendo datos para Viktor Fischer
# Obteniendo datos para Anthony Knockaert
# Obteniendo datos para Pozuelo
# Obteniendo datos para Gregoire Defrel
# Obteniendo datos para Alexander Schwolow
# Obteniendo datos para Willy Boly
# Obteniendo datos para Jesé
# Obteniendo datos para Aleix Vidal
# Obteniendo datos para Javi Espinosa
# Obteniendo datos para Serantes
# Obteniendo datos para Johannes Geis
# Obteniendo datos para Remo Freuler
# Obteniendo datos para Valentin Eysseric
# Obteniendo datos para Dmitriy Poloz
# Obteniendo datos para Frederik Sørensen
# Obteniendo datos para Ravel Morrison
# Obteniendo datos para Łukasz Teodorczyk
# Obteniendo datos para Marafona
# Obteniendo datos para Pedro Mendes
# Obteniendo datos para Christopher Schindler
# Obteniendo datos para Nico Schulz
# Obteniendo datos para Lukas Rupp
# Obteniendo datos para Alan Patrick
# Obteniendo datos para Lewis Dunk
# Obteniendo datos para Timor
# Obteniendo datos para Dennis Praet
# Obteniendo datos para André André
# Obteniendo datos para Gálvez
# Obteniendo datos para Ibai Gómez
# Obteniendo datos para Nathan Redmond
# Obteniendo datos para Raúl Navas
# Obteniendo datos para Óscar Murillo
# Obteniendo datos para Cláudio Ramos
# Obteniendo datos para Stefan Bell
# Obteniendo datos para Marco Höger
# Obteniendo datos para Sérgio Oliveira
# Obteniendo datos para Papy Djilobodji
# Obteniendo datos para Jonas Martin
# Obteniendo datos para Giannelli Imbula
# Obteniendo datos para Khouma Babacar
# Obteniendo datos para Adrien Regattin
# Obteniendo datos para Macnelly Torres
# Obteniendo datos para Danny Ings
# Obteniendo datos para Javi López
# Obteniendo datos para Borja Bastón
# Obteniendo datos para Laguardia
# Obteniendo datos para Nenad Tomović
# Obteniendo datos para Pontus Jansson
# Obteniendo datos para Keko
# Obteniendo datos para Andre Gray
# Obteniendo datos para Arnaud Souquet
# Obteniendo datos para Maxime Gonalons
# Obteniendo datos para Juanpe
# Obteniendo datos para Daniel Ginczek
# Obteniendo datos para Júnior Caiçara
# Obteniendo datos para Lamine Sané
# Obteniendo datos para Paul Lasne
# Obteniendo datos para Bruno César
# Obteniendo datos para Bóveda
# Obteniendo datos para Néstor Araujo
# Obteniendo datos para Fredy Montero
# Obteniendo datos para Kévin Théophile-Catherine
# Obteniendo datos para Tolgay Arslan
# Obteniendo datos para Tony Jantschke
# Obteniendo datos para Steven Zuber
# Obteniendo datos para Yoric Ravet
# Obteniendo datos para Łukasz Skorupski
# Obteniendo datos para Kiko Femenía
# Obteniendo datos para Éder
# Obteniendo datos para Tom Cleverley
# Obteniendo datos para Alcalá
# Obteniendo datos para Alex McCarthy
# Obteniendo datos para Bruno Fornaroli
# Obteniendo datos para Daniel Brosinski
# Obteniendo datos para Michel Macedo
# Obteniendo datos para Alfred N'Diaye
# Obteniendo datos para Admir Mehmedi
# Obteniendo datos para Ronny Rodelin
# Obteniendo datos para Juanfran
# Obteniendo datos para Rochina
# Obteniendo datos para Maicón
# Obteniendo datos para Omar El Kaddouri
# Obteniendo datos para Douglas
# Obteniendo datos para Maurício
# Obteniendo datos para Dayro Moreno
# Obteniendo datos para Cheikhou Kouyaté
# Obteniendo datos para Bernardo Espinosa
# Obteniendo datos para Franco Di Santo
# Obteniendo datos para Michał Pazdan
# Obteniendo datos para Maurício
# Obteniendo datos para Younousse Sankharé
# Obteniendo datos para Facundo Roncaglia
# Obteniendo datos para Simon Terodde
# Obteniendo datos para Daniel Schwaab
# Obteniendo datos para Marc Albrighton
# Obteniendo datos para Rúben Ribeiro
# Obteniendo datos para Beto
# Obteniendo datos para Sebastian De Maio
# Obteniendo datos para Koo Ja Cheol
# Obteniendo datos para Antonio Rukavina
# Obteniendo datos para Albin Ekdal
# Obteniendo datos para Ki Sung Yueng
# Obteniendo datos para Thomas Kraft
# Obteniendo datos para Emiliano Insúa
# Obteniendo datos para Miralem Sulejmani
# Obteniendo datos para Marko Marin
# Obteniendo datos para Papakouli Diop
# Obteniendo datos para Etienne Capoue
# Obteniendo datos para Lucas Deaux
# Obteniendo datos para Paul Baysse
# Obteniendo datos para Chico Flores
# Obteniendo datos para Fabian Lustenberger
# Obteniendo datos para Régis Gurtner
# Obteniendo datos para Bryan Ruíz
# Obteniendo datos para Mossoró
# Obteniendo datos para Adrián Ramos
# Obteniendo datos para Mariano Andújar
# Obteniendo datos para Andrew Surman
# Obteniendo datos para Javi Varas
# Obteniendo datos para Castán
# Obteniendo datos para Fraser Forster
# Obteniendo datos para Lasse Schøne
# Obteniendo datos para Jonatan Maidana
# Obteniendo datos para Paul Aguilar
# Obteniendo datos para Scott Sinclair
# Obteniendo datos para Cássio
# Obteniendo datos para Brad Jones
# Obteniendo datos para Marco Ruben
# Obteniendo datos para Ismael Sosa
# Obteniendo datos para Rolando
# Obteniendo datos para Erkan Zengin
# Obteniendo datos para Pirmin Schwegler
# Obteniendo datos para Gökhan İnler
# Obteniendo datos para Gelson Fernandes
# Obteniendo datos para Aaron Hunt
# Obteniendo datos para Scott Dann
# Obteniendo datos para Neri Cardozo
# Obteniendo datos para José de Jesús Corona
# Obteniendo datos para Renato Civelli
# Obteniendo datos para Rubens Sambueza
# Obteniendo datos para Mark Noble
# Obteniendo datos para Christophe Jallet
# Obteniendo datos para Sergey Ryzhikov
# Obteniendo datos para Andrés Fernández
# Obteniendo datos para Mikel Rico
# Obteniendo datos para Román Martínez
# Obteniendo datos para Pablo Zabaleta
# Obteniendo datos para Rafael
# Obteniendo datos para Jérémy Morel
# Obteniendo datos para Nicolás Burdisso
# Obteniendo datos para Alejandro Domínguez
# Obteniendo datos para Simon Francis
# Obteniendo datos para Alexis
# Obteniendo datos para Iraizoz
# Obteniendo datos para Jonas Olsson
# Obteniendo datos para Albano Bizzarri
# Obteniendo datos para John Terry
# Obteniendo datos para César Navas
# Obteniendo datos para Gareth Barry
# Obteniendo datos para Eliseu
# Obteniendo datos para Alan Franco
# Obteniendo datos para Malang Sarr
# Obteniendo datos para Dimitri Liénard
# Obteniendo datos para Houssem Aouar
# Obteniendo datos para Bruno Viana
# Obteniendo datos para Ramadan Sobhi
# Obteniendo datos para Gaku Shibasaki
# Obteniendo datos para Theo Hernández
# Obteniendo datos para Felix Uduokhai
# Obteniendo datos para Lato
# Obteniendo datos para Trent Alexander-Arnold
# Obteniendo datos para Renato Sanches
# Obteniendo datos para Mouctar Diakhaby
# Obteniendo datos para Mijat Gaćinović
# Obteniendo datos para Rafael Cachoira
# Obteniendo datos para Nicholas Aldair
# Obteniendo datos para Luimo Boas Santos
# Obteniendo datos para Adilson Edrada
# Obteniendo datos para Ailton Guevara
# Obteniendo datos para Allan Bardinho
# Obteniendo datos para Simão Acunha
# Obteniendo datos para Gabrisco Aníbal
# Obteniendo datos para Fabrio Farinha
# Obteniendo datos para Davi Parrela
# Obteniendo datos para Kaimo Lima
# Obteniendo datos para Victildinho
# Obteniendo datos para Lafortiscinho
# Obteniendo datos para Andeson Trigo
# Obteniendo datos para Kaíquão Castro
# Obteniendo datos para Dani Rochelinhas
# Obteniendo datos para Jorginhson
# Obteniendo datos para Melvin Parrela
# Obteniendo datos para Otávio Cairinho
# Obteniendo datos para Caio Nunson
# Obteniendo datos para Juli Freitinho
# Obteniendo datos para Alexo Baia
# Obteniendo datos para Silas Almeim
# Obteniendo datos para Simão Donatinho
# Obteniendo datos para Youssef Aït Bennasser
# Obteniendo datos para Córdoba
# Obteniendo datos para Hermoso
# Obteniendo datos para Palhinha
# Obteniendo datos para Mauricio Lemos
# Obteniendo datos para Manuel Akanji
# Obteniendo datos para Dalbert
# Obteniendo datos para Francisco Geraldes
# Obteniendo datos para Ferland Mendy
# Obteniendo datos para Edmilson Junior
# Obteniendo datos para Rodrigo Bentancur
# Obteniendo datos para Marko Dmitrović
# Obteniendo datos para André Horta
# Obteniendo datos para Thilo Kehrer
# Obteniendo datos para Sabin Merino
# Obteniendo datos para Thiago Maia
# Obteniendo datos para Kelechi Iheanacho
# Obteniendo datos para Jean-Kévin Augustin
# Obteniendo datos para Lekue
# Obteniendo datos para Andrés Ibargüen
# Obteniendo datos para Merino
# Obteniendo datos para Ellyes Skhiri
# Obteniendo datos para Lewis Cook
# Obteniendo datos para Sofyan Amrabat
# Obteniendo datos para Dyego Sousa
# Obteniendo datos para David Soria
# Obteniendo datos para Granell
# Obteniendo datos para Timo Baumgartl
# Obteniendo datos para Mata
# Obteniendo datos para Ivi
# Obteniendo datos para Harry Winks
# Obteniendo datos para Lukas Klostermann
# Obteniendo datos para Miloš Jojić
# Obteniendo datos para Hélder Costa
# Obteniendo datos para Miloš Veljković
# Obteniendo datos para Pablo Maffeo
# Obteniendo datos para Mislav Oršić
# Obteniendo datos para James Maddison
# Obteniendo datos para Demarai Gray
# Obteniendo datos para Tana
# Obteniendo datos para Baptiste Santamaria
# Obteniendo datos para Kahraba
# Obteniendo datos para Edgar Méndez
# Obteniendo datos para José Luis Gómez
# Obteniendo datos para Alejandro Silva
# Obteniendo datos para Djavan
# Obteniendo datos para Franco Mussis
# Obteniendo datos para Sebastián Torrico
# ...
# Obteniendo datos para Reece Webb-Foster
# Obteniendo datos para Krzysztof Karpieszuk
# Obteniendo datos para Rory Watson
# Obteniendo datos para Boris Babic
# Obteniendo datos para Nick Anderton
# Obteniendo datos para Konrad Andrzejczak
# Obteniendo datos para Charlie Burns
# Obteniendo datos para Aryan Tajbakhsh
# Obteniendo datos para Jamie McCombe
# Obteniendo datos para Erik Tallig
# Obteniendo datos para Sebastian Walukiewicz
# Obteniendo datos para Theophilus Awua
# Obteniendo datos para Edwin Herrera
# Obteniendo datos para Valentin Reitstetter
# Obteniendo datos para Marcus Backmann
# Obteniendo datos para Simon Pedersen
# Obteniendo datos para Daiju Sasaki
# Obteniendo datos para Johann Berger
# Obteniendo datos para Abdullah Saghir
# Obteniendo datos para Stefan Wolf
# Obteniendo datos para Adrian Benedyczak
# Obteniendo datos para Isak Magnusson
# Obteniendo datos para Juan Pablo Agudelo
# Obteniendo datos para Sebastián Palma
# Obteniendo datos para Tobias Schättin
# Obteniendo datos para Vladislav Poletaev
# Obteniendo datos para Adam Sørensen
# Obteniendo datos para Linus Nygren
# Obteniendo datos para Morten Frendrup
# Obteniendo datos para Jean-David Uras
# Obteniendo datos para Mathias-Alain Fischer
# Obteniendo datos para Efraín Navarro
# Obteniendo datos para Haruki Saruta
# Obteniendo datos para Bartłomiej Gradecki
# Obteniendo datos para Kai Shibato
# Obteniendo datos para Casper Hauervig
# Obteniendo datos para Sofiane Khayat
# Obteniendo datos para Melvin Frithzell
# Obteniendo datos para Matt Casey
# Obteniendo datos para Yanis Barka
# Obteniendo datos para Kasper Thiesson Kristensen
# Obteniendo datos para Yeison Arboleda
# Obteniendo datos para Mender García
# Obteniendo datos para Samuel Cartwright
# Obteniendo datos para Andreas Öhman
# Obteniendo datos para Adrian Edqvist
# Obteniendo datos para Pedro Teixeira
# Obteniendo datos para Michael Cooper
# Obteniendo datos para Tomás Durso
# Obteniendo datos para George Lloyd
# Obteniendo datos para Sebastian Friman
# Obteniendo datos para Antonee Burke-Gilroy
# Obteniendo datos para Theo Widdrington
# Obteniendo datos para Ozer Ozdemir
# Obteniendo datos para Vasiliy Lukichev
# Obteniendo datos para Kylian Ramè
# Obteniendo datos para Gustav Nyberg
# Obteniendo datos para Sylwester Lusiusz
# Obteniendo datos para Hamad Hawsawi
# Obteniendo datos para Kevin Humeler
# Obteniendo datos para Jared Muñoz
# Obteniendo datos para Sam Blake
# Obteniendo datos para Alexander Weidinger
# Obteniendo datos para Kalle Ekman
# Obteniendo datos para Izer Aliu
# Obteniendo datos para Tim Staubli
# Obteniendo datos para Silvan Gönitzer
# Obteniendo datos para Damien Dumont
# Obteniendo datos para Antonios Papadopoulos
# Obteniendo datos para Paul Schmieder
# Obteniendo datos para Marc Tokich
# Obteniendo datos para Mathias Andersen
# Obteniendo datos para Adrian Kappenberger
# Obteniendo datos para Pascal Kubina
# Obteniendo datos para Michał Gałecki
# Obteniendo datos para Tim Möller
# Obteniendo datos para Ángel
# Obteniendo datos para Jakob Gesien
# Obteniendo datos para Daniel Thøgersen
# Obteniendo datos para Julian Püschel
# Obteniendo datos para Stefan Schmidt
# Obteniendo datos para Kevin Tshiembe
# Obteniendo datos para Edvin Crona
# Obteniendo datos para Bernd Schipmann
# Obteniendo datos para Jordan Simpson
# Obteniendo datos para Tobias Damsgaard
# Obteniendo datos para Andrés Amaya
# Obteniendo datos para Ayaki Suzuki
# Obteniendo datos para Yohei Nishibe
# Obteniendo datos para Shunta Awaka
# Obteniendo datos para Scott Twine
# Obteniendo datos para Gaku Harada
# Obteniendo datos para Abdel Hakim Abdallah
# Obteniendo datos para Ashley Maynard-Brewer
# Obteniendo datos para Mohammed Al Zubaidi
# Obteniendo datos para Jose Hernandez
# Obteniendo datos para Marwan Bazi
# Obteniendo datos para Reagan Ogle
# Obteniendo datos para Diego Agamez
# Obteniendo datos para Dapo Kayode
# Obteniendo datos para Harry Pickering
# Obteniendo datos para Harry Pickering
# Obteniendo datos para Josh Thomas
# Obteniendo datos para Jordan Storey
# Obteniendo datos para Jacob Buus
# Obteniendo datos para Jakub Freitag
# Obteniendo datos para Viktor Anker
# Obteniendo datos para Takumi Hasegawa
# Obteniendo datos para Andrew Eleftheriou
# Obteniendo datos para Jetmir Krasniqi
# Obteniendo datos para Oliver Kjærgaard
# Obteniendo datos para Oscar Hedvall
# Obteniendo datos para Nicolaj Jørgensen
# Obteniendo datos para Hussain Al Khulaif
# Obteniendo datos para Kye Rowles
# Obteniendo datos para Alex Babos
# Obteniendo datos para Naoki Hatta
# Obteniendo datos para Dario Thürkauf
# Obteniendo datos para Emil Riis Jakobsen
# Obteniendo datos para Hugo
# Obteniendo datos para George Newell
# Obteniendo datos para Felix Hornung
# Obteniendo datos para Oscar Jonsson
# Obteniendo datos para Mathew Hudson
# Obteniendo datos para Alex Byrne
# Obteniendo datos para Matthew Jay
# Obteniendo datos para Steve Phillips
# Obteniendo datos para Camilo Ariza
# Obteniendo datos para John Quiñones Saya
# Obteniendo datos para Juan Diego Nieva
# Obteniendo datos para Jonathan Harboe
# Obteniendo datos para Kota Yamada
# Obteniendo datos para Oliver Klitten
# Obteniendo datos para Adam Bark
# Obteniendo datos para Alexander H. Jensen
# Obteniendo datos para Kevin Agudelo
# Obteniendo datos para Ben-Luca Moritz
# Obteniendo datos para Kasper Høgh
# Obteniendo datos para Daniel Liszka
# Obteniendo datos para Wojciech Sadlowski
# Obteniendo datos para Yanick Hofer
# Obteniendo datos para Ali Al Hassan
# Obteniendo datos para Alexandr Akishin
# Obteniendo datos para Sherko Faiqi
# Obteniendo datos para Jean-François Finidori
# Obteniendo datos para Alexandre Troffa
# Obteniendo datos para Steven N'Guessan
# Obteniendo datos para Joe White
# Obteniendo datos para Pacifique Niyongabire
# Obteniendo datos para Angus Thurgate
# Obteniendo datos para Mohammad Al Sharimi
# Obteniendo datos para So Nakagawa
# Obteniendo datos para Callum Timmins
# Obteniendo datos para Albert Makiadi
# Obteniendo datos para Isaac Richards
# Obteniendo datos para Sam Fielding
# Obteniendo datos para Matty Wolfe
# Obteniendo datos para George Hornshaw
# Obteniendo datos para Søren Gustav Bugge Jepsen
# Obteniendo datos para Esteban Pérez
# Obteniendo datos para Rasmus Wiedesheim-Paul
# Obteniendo datos para Kristin Konstandopoulos
# Obteniendo datos para Lipe Veloso
# Obteniendo datos para Taiyo Hama
# Obteniendo datos para Julian Tomas
# Obteniendo datos para Khamzat Nasurov
# Obteniendo datos para Simon Vollesen
# Obteniendo datos para Mersim Asllani
# Obteniendo datos para Saleh Al Nashmi
# Obteniendo datos para Mazen Al Suwailem
# Obteniendo datos para Min Gyeong Min
# Obteniendo datos para Luke Russe
# Obteniendo datos para Tobias Kraulich
# Obteniendo datos para Tom Anderson
# Obteniendo datos para Cameron Sangster
# Obteniendo datos para Leo Petri
# Obteniendo datos para Marcel Ruschmeier
# Obteniendo datos para Jordan Morris
# Obteniendo datos para Frederik Roepstorff
# Obteniendo datos para James Delianov
# Obteniendo datos para Steven Yawson
# Obteniendo datos para Jean Carlos Pestaña
# Obteniendo datos para Magnus Warming
# Obteniendo datos para Christian Enemark
# Obteniendo datos para Jack Sims
# Obteniendo datos para Lewis Reilly
# Obteniendo datos para Takeaki Harigaya
# Obteniendo datos para Joe Slinn
# Obteniendo datos para Ryohei Michibuchi
# Obteniendo datos para Ryuji Kawai
# Obteniendo datos para Dylan Pierias
# Obteniendo datos para Ryotaro Meshino
# Obteniendo datos para Riku Yamada
# Obteniendo datos para Ben Hedley
# Obteniendo datos para Owen Dale
# Obteniendo datos para Jeppe Gertsen
# Obteniendo datos para Park Chun Ho
# Obteniendo datos para Ashley Nadesan
# Obteniendo datos para Benjamin Hvidt
# Obteniendo datos para Emil Damgaard
# Obteniendo datos para Takanori Maeno
# Obteniendo datos para Adam Fägerhag
# Obteniendo datos para Ryan Wintle
# Obteniendo datos para Jesse Curran
# Obteniendo datos para Dan Sweeney
# Obteniendo datos para Jannik Skov Hansen
# Obteniendo datos para Patrick Jennings
# Obteniendo datos para Victor Smedsrud
# Obteniendo datos para Kevin Yakob
# Obteniendo datos para Julian Conze
# Obteniendo datos para Adrián Estacio
# Obteniendo datos para Jonathan Eriksen
# Obteniendo datos para Mathias Jørgensen
# Obteniendo datos para Sean Whaler
# Obteniendo datos para Jeon Ji Hyun
# Obteniendo datos para Julian Guttau
# Obteniendo datos para Sebastián Guzmán
# Obteniendo datos para Santiago Noreña
# Obteniendo datos para Declan O'Hare
# Obteniendo datos para Jean-Gabriel Pierazzi
# Obteniendo datos para Simon Graves
# Obteniendo datos para Illan Meslier
# Obteniendo datos para Julien Ponceau
# Obteniendo datos para Niklas Strunck
# Obteniendo datos para Dawid Błanik
# Obteniendo datos para Michael Antkowiak
# Obteniendo datos para Harrison Biggins
# Obteniendo datos para Yahia Fofana
# Obteniendo datos para Matthew Sutton
# Obteniendo datos para Will Dawes
# Obteniendo datos para Ethan Lamptey
# Obteniendo datos para Pape Gueye
# Obteniendo datos para Daniel Butterworth
# Obteniendo datos para Joaquín Mendive
# Obteniendo datos para Oscar Petersson
# Obteniendo datos para Emil Wikström
# Obteniendo datos para Finlay Sinclair-Smith
# Obteniendo datos para Apostolos Stamatelopoulos
# Obteniendo datos para Shu Mogi
# Obteniendo datos para Akinari Kawazura
# Obteniendo datos para Jake Ellis
# Obteniendo datos para Frederik Nørgaard
# Obteniendo datos para Cameron Hargreaves
# Obteniendo datos para Callum Gunner
# Obteniendo datos para Joel Grodowski
# Obteniendo datos para Tom Knowles
# Obteniendo datos para Markus Iversen
# Obteniendo datos para Jack Egan
# Obteniendo datos para Connor Metcalfe
# Obteniendo datos para Mark Moric
# Obteniendo datos para Diego Berchtold
# Obteniendo datos para Joel García
# Obteniendo datos para Denis Adamov
# Obteniendo datos para Benjamin Tannus
# Obteniendo datos para Krzysztof Kurek
# Obteniendo datos para Johan Stenmark
# Obteniendo datos para Leon Demaj
# Obteniendo datos para Nico Mantl
# Obteniendo datos para Callum Roberts
# Obteniendo datos para Alexander Arvidsson
# Obteniendo datos para Ardian Berisha
# Obteniendo datos para James Goff
# Obteniendo datos para Brandon Ganley
# Obteniendo datos para Ryu Eon Jae
# Obteniendo datos para Cameron McGilp
# Obteniendo datos para Yutaka Soneda
# Obteniendo datos para Goson Sakai
# Obteniendo datos para Michel Termanini
# Obteniendo datos para Ramón Pasquel
# Obteniendo datos para Jordan Holt
# Obteniendo datos para Nick Suman
# Obteniendo datos para Arthur Read
# Obteniendo datos para Nicolai Dohn
# Obteniendo datos para Edvin Dahlqvist
# Obteniendo datos para Matthias Hamrol
# Obteniendo datos para Jakob Johansson
# Obteniendo datos para Mads Emil Madsen
# Obteniendo datos para Mohammed Al Saeed
# Obteniendo datos para Atsushi Kurokawa
# Obteniendo datos para Teruhito Nakagawa
# Obteniendo datos para Paweł Żyra
# Obteniendo datos para Carl Stewart
# Obteniendo datos para Sam Hornby
# Obteniendo datos para Victor Adeboyejo
# Obteniendo datos para Andrew Mills
# Obteniendo datos para Karim Fegrouche
# Obteniendo datos para Maximilian Breunig
# Obteniendo datos para Magnus Westergaard
# Obteniendo datos para Felix Konstandeliasz
# Obteniendo datos para Moussa Ndiaye
# Obteniendo datos para Anthony Lesiotis
# Obteniendo datos para Alex Battle
# Obteniendo datos para Danny Horton
# Obteniendo datos para Moataz Al Baqawi
# Obteniendo datos para Zehn Mohammed
# Obteniendo datos para Szymon Więckowicz
# Obteniendo datos para Jhan Cuero
# Obteniendo datos para Justin Schau
# Obteniendo datos para Fatih Ufuk
# Obteniendo datos para Taylor Maloney
# Obteniendo datos para Taishi Matsumoto
# Obteniendo datos para Luke Jordan
# Obteniendo datos para Finley Iron
# Obteniendo datos para Krzysztof Miroszka
# Obteniendo datos para Omer Dzonlagic
# Obteniendo datos para Niall Maher
# Obteniendo datos para Mizuki Ichimaru
# Obteniendo datos para Yuto Mori
# Obteniendo datos para Morgan Bacon
# Obteniendo datos para Oliver Finney
# Obteniendo datos para Matthew Foy
# Obteniendo datos para Pichkah Paya
# Obteniendo datos para Jonas Olofsson
# Obteniendo datos para Jakub Bursztyn
# Obteniendo datos para Julián Lemos
# Obteniendo datos para Esben Andreassen
# Obteniendo datos para Hans Oeftger
# Obteniendo datos para Morgan Roberts
# Obteniendo datos para Alfie Jones
# Obteniendo datos para Calvin Heim
# Obteniendo datos para Kyle Hawley
# Obteniendo datos para Niall Watson
# Obteniendo datos para Toshiaki Miyamoto
# Obteniendo datos para Daniel Rooney
# Obteniendo datos para Jordan Gibson
# Obteniendo datos para Christoph Ehlich
# Obteniendo datos para Stefano Guidotti
# Obteniendo datos para Reo Takae
# Obteniendo datos para Yoshihiro Uchimura
# Obteniendo datos para Mamadou Djabi
# Obteniendo datos para Junto Taguchi
# Obteniendo datos para Takuya Yasui
# Obteniendo datos para Ron Schallenberg
# Obteniendo datos para Josh Lundstram
# Obteniendo datos para Kotaro Fujikawa
# Obteniendo datos para Kim Yun Soo
# Obteniendo datos para Keita Irumagawa
# Obteniendo datos para Tyler Brownsword
# Obteniendo datos para Louis Jones
# Obteniendo datos para Adam Kelsey
# Obteniendo datos para Tommy Käßemodel
# Obteniendo datos para Nathan Sheron
#                           Name     Nationality Rating
# 0            Cristiano Ronaldo        Portugal     94
# 1                Kylian Mbappé          France     84
# 2                 Lionel Messi       Argentina     94
# 3                Mohamed Salah           Egypt     87
# 4                       Neymar          Brazil     92
# 5            Antoine Griezmann          France     88
# 6                Gabriel Jesus          Brazil     83
# 7               Lucas Torreira         Uruguay     78
# 8                 Thomas Lemar          France     83
# 9               Gelson Martins        Portugal     82
# 10             Marcus Rashford         England     81
# 11                Paulo Dybala       Argentina     89
# 12             Ousmane Dembélé          France     83
# 13               Marco Asensio           Spain     84
# 14                    Coutinho          Brazil     87
# 15                  Paul Pogba          France     88
# 16                  Leroy Sané         Germany     85
# 17             Roberto Firmino          Brazil     85
# 18            Alexandr Golovin          Russia     79
# 19                 Eden Hazard         Belgium     91
# 20             Bruno Fernandes        Portugal     82
# 21                N'Golo Kanté          France     88
# 22                  Sadio Mané         Senegal     84
# 23          Zlatan Ibrahimović          Sweden     86
# 24              Joshua Kimmich         Germany     84
# 25             Anthony Martial          France     83
# 26            Giovani Lo Celso       Argentina     77
# 27     Sergej Milinković-Savić          Serbia     83
# 28             Kevin De Bruyne         Belgium     91
# 29          Robert Lewandowski          Poland     91
# ...                        ...             ...    ...
# 12160           Jonas Olofsson          Sweden     48
# 12161           Jakub Bursztyn          Poland     48
# 12162             Julián Lemos        Colombia     48
# 12163         Esben Andreassen         Denmark     48
# 12164             Hans Oeftger         Germany     48
# 12165           Morgan Roberts         England     48
# 12166              Alfie Jones         England     48
# 12167              Calvin Heim     Switzerland     48
# 12168              Kyle Hawley         England     48
# 12169             Niall Watson         England     48
# 12170        Toshiaki Miyamoto           Japan     48
# 12171            Daniel Rooney         England     48
# 12172            Jordan Gibson         England     48
# 12173         Christoph Ehlich         Germany     48
# 12174         Stefano Guidotti     Switzerland     48
# 12175                Reo Takae           Japan     48
# 12176       Yoshihiro Uchimura           Japan     48
# 12177            Mamadou Djabi         England     48
# 12178            Junto Taguchi           Japan     48
# 12179             Takuya Yasui           Japan     47
# 12180         Ron Schallenberg         Germany     47
# 12181           Josh Lundstram         England     47
# 12182          Kotaro Fujikawa           Japan     47
# 12183              Kim Yun Soo  Korea Republic     47
# 12184          Keita Irumagawa           Japan     47
# 12185         Tyler Brownsword         England     47
# 12186              Louis Jones         England     47
# 12187              Adam Kelsey         England     46
# 12188          Tommy Käßemodel         Germany     46
# 12189            Nathan Sheron         England     46
#
# [12190 rows x 3 columns]

# %%
## Guarda archivo en plano csv
df1.to_csv('Full_details.csv', index = False, encoding = 'utf-8', sep = ";", date_format='%m/%d/%Y')

# %%
df1.head(20)
# Out:
#                  Name Nationality National_Position National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS            7
# 1       Kylian Mbappé      France                RM           10
# 2        Lionel Messi   Argentina                RW           10
# 3       Mohamed Salah       Egypt               Sub           10
# 4              Neymar      Brazil                LW           10
# 5   Antoine Griezmann      France               CAM            7
# 6       Gabriel Jesus      Brazil                ST            9
# 7      Lucas Torreira     Uruguay               Sub           14
# 8        Thomas Lemar      France                LM            8
# 9      Gelson Martins    Portugal               Sub           18
# 10    Marcus Rashford     England                LS           11
# 11       Paulo Dybala   Argentina
# 12    Ousmane Dembélé      France               Sub           11
# 13      Marco Asensio       Spain               Sub           20
# 14           Coutinho      Brazil                RW           11
# 15         Paul Pogba      France               RDM            6
# 16         Leroy Sané     Germany
# 17    Roberto Firmino      Brazil               Sub           21
# 18   Alexandr Golovin      Russia               LCM           17
# 19        Eden Hazard     Belgium                LF           10
#
#                Club Club_Position Club_Kit Club_Joining Contract_Expiry  \
# 0       Real Madrid            LW        7   07/01/2009            2021
# 1               PSG            RW       29   12/02/2015            2019
# 2      FC Barcelona            RS       10   07/01/2004            2021
# 3         Liverpool            RW       11   07/01/2017            2022
# 4               PSG            LW       10   08/03/2017            2022
# 5   Atlético Madrid            RS        7   07/29/2014            2022
# 6   Manchester City           Sub       33   08/03/2016            2021
# 7         Sampdoria            CM       34   07/01/2015            2022
# 8         AS Monaco            LM       27   06/27/2015            2020
# 9       Sporting CP            RM       77   07/01/2014            2022
# 10   Manchester Utd           Sub       19   07/01/2014            2020
# 11         Juventus            RW       10   07/01/2015            2022
# 12     FC Barcelona            RM       11   08/28/2017            2022
# 13      Real Madrid           Sub       20   01/22/2015            2023
# 14     FC Barcelona            LM       14   01/06/2018            2023
# 15   Manchester Utd           LCM        6   08/09/2016            2021
# 16  Manchester City            LW       19   08/02/2016            2021
# 17        Liverpool            ST        9   07/06/2015            2023
# 18      CSKA Moscow           LCM       17   07/24/2013            2021
# 19          Chelsea            LW       10   07/01/2012            2020
#
#    Rating     ...     Long_Shots Curve Freekick_Accuracy Penalties Volleys  \
# 0      94     ...             92    81                76        85      88
# 1      84     ...             69    76                58        70      74
# 2      94     ...             88    90                92        75      86
# 3      87     ...             81    82                60        61      73
# 4      92     ...             78    82                84        81      83
# 5      88     ...             82    84                75        72      87
# 6      83     ...             73    76                54        78      72
# 7      78     ...             74    66                74        48      65
# 8      83     ...             76    81                81        68      75
# 9      82     ...             73    84                60        66      74
# 10     81     ...             71    77                78        74      72
# 11     89     ...             88    88                88        86      88
# 12     83     ...             65    78                65        75      76
# 13     84     ...             87    83                76        62      79
# 14     87     ...             87    84                84        70      75
# 15     88     ...             82    84                82        76      85
# 16     85     ...             77    82                68        67      72
# 17     85     ...             76    80                67        72      81
# 18     79     ...             75    75                77        52      70
# 19     91     ...             80    83                79        86      80
#
#    GK_Positioning GK_Diving  GK_Kicking  GK_Handling GK_Reflexes
# 0              14         7          15           11          11
# 1              11        13           7            5           6
# 2              14         6          15           11           8
# 3              11        14           9           14          14
# 4              15         9          15            9          11
# 5              13        14          14            8          14
# 6               6        13           6            8          15
# 7               7         5          13            5           9
# 8               7        11          13           15          14
# 9               6        12           7            9           9
# 10              7        11          15            6          14
# 11              5         5           4            4           8
# 12             10         6          14            6          13
# 13             12        13           6            9          10
# 14             14        12           9            7           6
# 15              4         5           2            6           3
# 16              9         8           9           12          14
# 17              6         8           9           11          10
# 18             10        12          14           14          16
# 19              8        11           6           12           8
#
# [20 rows x 53 columns]
